# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model="openai/gpt-oss-120b", temperature=0)

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The Moon isn’t a country or a political entity, so it doesn’t have a capital city. It’s a natural satellite of Earth, and while there are several lunar bases and proposed settlement concepts (like the planned Artemis Base Camp), none of them serve as an official “capital.”

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# **Lunaris Prime – The Capital of the Moon**
#
# *Official Designation:* **Lunaris Prime** (sometimes simply called *The Prime*).
# *Coordinates:* 0° N, 0° E (the exact center of the near‑side Mare Imbrium, directly beneath the Earth‑facing point of the Moon).
# *Population:* ~12 million permanent residents (a mix of Earth‑born colonists, lunar‑born “Lunites,” and a growing community of AI‑managed habitats).
# *Governance:* The Lunar Commonwealth Council, a 27‑member body elected from the Moon’s major settlement zones, meets in the **Crescent Hall**.
#
# ---
#
# ### A Brief History
#
# | Year (Earth) | Milestone |
# |--------------|-----------|
# | 2035 | First permanent research outpost, **Artemis Base‑1**, established in Mare Tranquillitatis. |
# | 2052 | The **LunaRail** magnetic‑levitation network links the first three bases, creating the first “city‑cluster.” |
# | 2078 | The **Lunar Charter** is ratified, granting the Moon a semi‑autonomous status within the United Earth Federation. |
# | 2091 | Construction of **Crescent Hall** begins; the city’s layout is finalized by the International Lunar Planning Committee. |
# | 2104 | **Lunaris Prime** is officially inaugurated as the capital of the Lunar Commonwealth. |
#
# ---
#
# ### City Layout
#
# Lunaris Prime is built in concentric “rings” that follow the natural curvature of the lunar surface, each ring serving a distinct purpose:
#
# 1. **The Core (The Crater)**
#    - **Crescent Hall:** A domed, transparent‑aluminum structure that houses the Commonwealth Council chambers, the Lunar Supreme Court, and the diplomatic quarter.
#    - **The Archive:** A deep‑vaulted repository of Earth‑Moon history, stored on quantum‑entangled crystal matrices.
#    - **Zero‑Gravity Plaza:** A public space where citizens experience gentle rotation, allowing short periods of weightlessness for recreation and art.
#
# 2. **The Ring of Light (Residential Belt)**
#    - **Habitat Pods:** Modular, inflatable living units with adjustable radiation shielding. Each pod can be re‑configured for families, single occupants, or communal co‑ops.
#    - **Green‑Dome Gardens:** Hydroponic farms and bioluminescent orchards that provide fresh food and oxygen, illuminated by a combination of solar mirrors and engineered glow‑plants.
#    - **Cultural Quarters:** The **Lunar Opera**, **Starlight Museum**, and the **Moon‑Verse Library** (a multilingual repository of Earth and lunar literature).
#
# 3. **The Ring of Industry (Economic Belt)**
#    - **Regolith Refineries:** Facilities that extract oxygen, water, and building materials from the lunar soil.
#    - **Space‑Port Nexus:** A series of launch pads and docking bays for cargo shuttles, lunar‑surface rovers, and orbital elevators that connect to the **Luna‑Orbital Ring** (a massive space‑station orbiting at 100 km altitude).
#    - **Manufacturing Pods:** 3‑D‑printing factories that produce everything from satellite components to spare parts for the city’s infrastructure.
#
# 4. **The Ring of Defense (Security Belt)**
#    - **Shield Array:** A network of electromagnetic deflectors that mitigate solar particle events and micrometeorite impacts.
#    - **Lunar Guard Headquarters:** Home to the **Lunar Peacekeepers**, a mixed force of human officers and autonomous drones tasked with maintaining order and protecting the city from external threats.
#
# ---
#
# ### Daily Life in Lunaris Prime
#
# - **Transportation:** Citizens glide along the **LunaRail**—a magnetic‑levitation loop that circles the city at 150 km/h, with stations every 5 km. Personal “hover‑pods” are also common for short trips.
# - **Economy:** The city’s economy thrives on **regolith mining**, **helium‑3 extraction** for fusion power, and **space‑tourism** (the “Moon‑Orbit Cruise” is a popular package). A thriving market of artisanal crafts—moon‑glass jewelry, low‑gravity ceramics, and photon‑woven textiles—adds cultural flavor.
# - **Education:** The **Lunar Academy** offers curricula in astro‑engineering, exobiology, and lunar law. Children attend “gravity‑adjusted” classes where they can float for short periods to study physics in a hands‑on environment.
# - **Culture:** Annual festivals celebrate both Earth heritage and lunar identity. The most famous is **“Eclipse Night,”** when Earth’s shadow passes over the Moon, and citizens gather in the Zero‑Gravity Plaza to watch the Earth rise, illuminated by the Sun’s rim.
#
# ---
#
# ### Why It’s Called “Lunaris Prime”
#
# - **Lunaris** evokes the Moon’s ancient name (Luna) while hinting at its new, luminous role as a hub of human civilization.
# - **Prime** denotes its status as the first, foremost seat of lunar governance and the symbolic “first city” beyond Earth.
#
# ---
#
# ### Fun Fact
#
# The **Moon‑Echo** is a natural acoustic phenomenon unique to Lunaris Prime’s central dome. Because the dome’s interior is lined with a thin layer of regolith‑infused polymer, any sound made inside reverberates for exactly **7.38 seconds**—the same period it takes the Moon to complete one rotation relative to the stars. Visitors often test the echo by shouting “Hello, Earth!” and listening for the delayed reply that seems to come from the very surface of the Moon itself.
#
# ---
#
# **So, while the Moon doesn’t have a capital in the real world—yet—imagine Lunaris Prime rising from the Sea of Tranquility, a shining beacon of humanity’s next great frontier.**

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunara

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# **Name:** Selene Prime
#
# **Location:** Mare Tranquillitatis, the central basin of the Moon’s near side, built into a network of domed habitats and underground caverns beneath the basaltic plain.
#
# **Vibe:** Luminous, Frontier‑like
#
# **Economy:** Lunar mining & rare‑earth extraction, orbital launch services, zero‑gravity research labs, and tourism hospitality.

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunaris Prime', location='Mare Imbrium, near the Shackleton crater at the lunar south pole', vibe='high-tech, scientific hub with a serene, otherworldly atmosphere', economy='lunar helium-3 mining, space tourism, research labs, and orbital trade')

# %%
response["structured_response"].name
# Out:
# 'Lunaris Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunaris Prime is a city located at Mare Imbrium, near the Shackleton crater at the lunar south pole
