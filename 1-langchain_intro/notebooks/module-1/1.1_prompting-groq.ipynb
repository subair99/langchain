# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="groq:openai/gpt-oss-120b")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The Moon isn’t a country or a political entity, so it doesn’t have a capital city. It’s a natural satellite of Earth with features like the Sea of Tranquility, the lunar highlands, and the far side’s “dark side,” but no official settlements or capitals—at least not yet! (Future lunar bases might one day adopt names, but for now there’s none.)

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="groq:openai/gpt-oss-120b",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# **Lunaris Prime – The Capital of the Moon**
#
# *Location:*
# Perched on the rim of the ancient **Mare Tranquillitatis**, Lunaris Prime occupies a massive, partially‑submerged basaltic plateau that stretches over 150 km. The city’s core sits within a series of interconnected lava‑tube caverns, while its outer districts fan out across the regolith‑covered highlands, giving the capital a layered, “city‑within‑a‑city” feel.
#
# ---
#
# ### 1. **City Layout**
#
# | District | Key Features | Purpose |
# |----------|--------------|---------|
# | **The Dome of Dawn** | A gleaming, geodesic dome of transparent aluminum that captures the first 14 seconds of lunar sunrise. Inside, hydroponic farms, a solar‑energy lattice, and the **Council Hall** (the seat of the Lunar Senate). | Governance & food production |
# | **The Regolith Ring** | A spiraling belt of pressurized habitats built into the rim of Mare Tranquillitatis. The outermost ring houses the **Lunar Port**, where cargo shuttles dock, and the inner ring contains residential towers with rotating gravity floors. | Transportation & housing |
# | **The Crater Bazaar** | Carved into the interior of the ancient **Tycho** crater, this open‑air market uses low‑gravity levitation pads to display exotic goods—Moon‑grown bioluminescent fungi, rare Helium‑3 crystals, and artifacts from early Earth‑Moon missions. | Commerce & culture |
# | **The Observatory Spire** | A 12‑km tall tower that pierces the thin exosphere, equipped with a **Quantum Interferometer Array** for deep‑space observation, and a **Lunar Timekeeper** that regulates the city’s synchronized 28‑day lunar calendar. | Science & navigation |
# | **The Sub‑Lunar Archives** | Hidden deep within a network of basaltic lava tubes, this vault stores the collective memory of humanity’s lunar heritage: digitized logs of Apollo missions, early colonist diaries, and the **Ethereal Library**, a holographic repository of all known knowledge. | History & education |
# | **The Gravity Gardens** | Terraced bio‑domes that spin slowly to create 0.3 g, allowing Earth‑type agriculture and recreation. The gardens are also home to the **Moon’s Symphony**, a kinetic art installation that turns wind‑generated dust storms into music. | Leisure & sustainability |
#
# ---
#
# ### 2. **Governance**
#
# Lunaris Prime is ruled by the **Lunar Senate**, a council of 27 representatives—each elected from one of the city’s districts. The Senate meets in the **Council Hall**, a circular chamber whose walls are lined with reflective regolith panels that capture and amplify the soft lunar light. Decisions are made by a combination of direct vote and **Quantum Consensus Algorithms**, which process the preferences of citizens across the Moon’s various habitats in real time.
#
# The **High Commissioner**—currently *Arielle Kwan*—acts as the chief executive, overseeing inter‑planetary diplomacy, trade regulation (especially Helium‑3 extraction), and the enforcement of the **Lunar Charter**, a set of laws that guarantee the protection of the Moon’s environment and the rights of all lunar residents, whether Earth‑born, Martian, or off‑worlder.
#
# ---
#
# ### 3. **Economy & Resources**
#
# - **Helium‑3 Mining:** The primary export, harvested from the regolith and refined in the **Plasma Foundries** beneath the Regolith Ring.
# - **Lunar Agriculture:** The Gravity Gardens supply fresh produce not only for the Moon but also for orbital habitats and Martian colonies.
# - **Tourism:** The **Crater Bazaar** and the **Observatory Spire** attract millions of visitors each Earth year, who pay in **Lunars**, the Moon’s digital currency backed by a reserve of Helium‑3.
# - **Research & Development:** The **Observatory Spire** and **Sub‑Lunar Archives** host multinational research teams working on low‑gravity physics, quantum communications, and terraforming technologies.
#
# ---
#
# ### 4. **Culture & Identity**
#
# Lunarians celebrate the **Festival of First Light** on the 1st day of each lunar month, when the city’s central dome opens its shutters to the sunrise, flooding the streets with amber light. Music, poetry, and holographic performances recount the saga of humanity’s journey from Earth to the Moon, while the **Moon’s Symphony** provides a constantly evolving soundtrack.
#
# The city’s motto, etched in basalt at the entrance of the Council Hall, reads:
#
# > *“From dust we rise, together we shine.”*
#
# ---
#
# ### 5. **Living on the Moon**
#
# Every citizen of Lunaris Prime lives in a **pressurized habitat module** that maintains a comfortable 1 atm pressure and a gentle 0.16 g gravity (achieved via rotating floor sections). Daily life includes:
#
# - **Commutes** on magnetic levitation pods that glide through vacuum tunnels.
# - **Meals** prepared from a blend of hydroponic greens, cultured protein, and occasional Earth‑imported delicacies.
# - **Education** in the **Lunar Academy**, where children learn both Earth history and lunar engineering.
# - **Recreation** in the **Zero‑G Arena**, where sports like “Lunar Ball” (a hybrid of volleyball and gymnastics) are played in micro‑gravity.
#
# ---
#
# ### 6. **Future Horizons**
#
# Plans are already underway for the **Lunar Expansion Project**, which aims to connect Lunaris Prime with a network of **Moon‑Ring Cities** around the far side, linked by high‑speed maglev tunnels and a shared energy grid powered by the **Lunar Reflector Array**—a series of orbital mirrors that beam concentrated sunlight to the Moon’s night side.
#
# ---
#
# **In short:** The capital of the Moon isn’t a single building or a barren plain—it’s **Lunaris Prime**, a thriving, multi‑layered metropolis that blends cutting‑edge technology, sustainable living, and a deep reverence for humanity’s celestial heritage. Whether you’re a scientist, a trader, or a dreamer looking for the next horizon, Lunaris Prime stands as the beating heart of lunar civilization.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="groq:openai/gpt-oss-120b",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Scifi Writer: Lunara Prime

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="groq:openai/gpt-oss-120b",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# **Name:** Selene‑Prime
#
# **Location:** The sprawling, domed megastructure rises from the central plateau of the Mare Imbrium, anchored to the ancient basaltic cliffs that rim the “Lunar Sea.” Its lower levels are carved directly into the regolith, while the upper tiers hover on magnetic levitation pads above the crater‑filled plain.
#
# **Vibe:** Luminous, bustling, frontier‑spirit
#
# **Economy:**
# - **Regolith Mining & Helium‑3 Extraction:** Massive vacuum‑sealed refineries process lunar soil for rare gases, metals, and construction materials.
# - **Orbital Trade Hub:** A nexus for interplanetary cargo shuttles, connecting Earth, Mars, and the asteroid belt; customs, logistics, and finance flourish in the high‑orbit docking rings.
# - **Research & Development:** State‑of‑the‑art labs focus on low‑gravity manufacturing, quantum communications, and terraforming prototypes.
# - **Tourism & Culture:** Transparent observation decks, zero‑gravity parks, and historic sites (e.g., the original Apollo landing pads) draw millions of visitors each year.
#
# Selene‑Prime serves as the political and cultural heart of humanity’s lunar presence, a shining beacon of cooperation and ambition perched on the Moon’s ancient seas.

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model="groq:openai/gpt-oss-120b",
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunaris City', location='Mare Imbrium, near the north pole of the Moon', vibe='Futuristic, serene, and luminous, blending ancient lunar myths with cutting-edge technology', economy='High-tech research, asteroid mining trade, and lunar tourism')

# %%
response["structured_response"].name
# Out:
# 'Lunaris City'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunaris City is a city located at Mare Imbrium, near the north pole of the Moon
