# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="openai/gpt-oss-120b", temperature=0)

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model=llm)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The Moon isn’t a country or a political entity, so it doesn’t have a capital city. It’s a natural satellite of Earth, and while there are several lunar bases and proposed settlement concepts (like the planned Artemis Base Camp), none of them serve as an official “capital.”

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=llm,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# **Lunaris Prime – The Capital of the Moon**
#
# *Official Designation:* **Lunaris Prime** (sometimes simply called *The Prime*).
# *Coordinates:* 0° N, 0° E (the exact center of the near‑side Mare Imbrium, directly beneath the Earth‑facing point of the Moon).
# *Population:* ~12 million permanent residents (a mix of Earth‑born colonists, lunar‑born “Lunites,” and a growing community of AI‑managed habitats).
# *Governance:* The Lunar Commonwealth Council, a 27‑member body elected from the Moon’s major settlement zones, meets in the **Craters Hall** of the capital.
#
# ---
#
# ### A Brief History
#
# | Year (Earth) | Milestone |
# |--------------|-----------|
# | 2035 | First permanent research outpost (Artemis‑3) established in Mare Imbrium. |
# | 2052 | The “Regolith Accord” creates the Lunar Settlement Charter, granting self‑governance to lunar colonies. |
# | 2078 | The **Luna‑City Initiative** consolidates scattered habitats into a single, interconnected megastructure. |
# | 2094 | The capital is officially named **Lunaris Prime** after a popular vote. |
# | 2101 | Completion of the **Craters Hall** and the **Solaris Dome**, marking the city’s functional independence. |
# | 2120 | First lunar‑born child is born in Lunaris Prime, cementing the Moon’s status as a true homeworld. |
#
# ---
#
# ### City Layout
#
# Lunaris Prime is built as a **radial megastructure** that hugs the interior walls of a massive, partially excavated crater—**Mare Imbrium’s “Crown Basin.”** The design balances three core principles:
#
# 1. **Radiation Shielding** – Thick layers of regolith (up to 12 m) line the outer walls, supplemented by graphene‑reinforced polymer panels.
# 2. **Closed‑Loop Life Support** – Every district recycles air, water, and waste through bio‑reactors that use engineered algae and extremophile microbes.
# 3. **Earth‑Moon Connectivity** – A network of maglev “Luna‑Rails” links the capital to other lunar settlements, while the **Eclipse Port** handles cargo and passenger traffic to Earth.
#
# #### Major Districts
#
# | District | Highlights |
# |----------|------------|
# | **Craters Hall** | Governmental hub; houses the Lunar Commonwealth Council, the Supreme Archive (a quantum‑indexed library of all lunar knowledge), and the Hall of Mirrors (a cultural center with holographic art). |
# | **Solaris Dome** | The largest transparent dome on the Moon, powered by a lattice of thin‑film solar panels. Inside, a climate‑controlled biosphere supports forests, farms, and recreation areas. |
# | **Regolith Market** | A bustling bazaar where Earth‑imported goods, lunar‑crafted tools, and exotic “space‑cuisine” are traded. The market’s central atrium features a zero‑gravity fountain of ionized plasma. |
# | **Starlight Quarters** | Residential zone with modular habitats that can be reconfigured as families grow. Each unit has a “view‑port” that projects live Earth vistas or deep‑space panoramas. |
# | **Neuro‑Forge** | The industrial heart: 3‑D‑printed habitats, mining equipment, and AI‑run fabrication plants. The Forge’s exhaust is filtered and fed back into the city’s life‑support loops. |
# | **Luna‑Port** | The primary launch/landing complex, equipped with electromagnetic launch pads for cargo shuttles and a “Sky‑Dock” for passenger liners traveling to Earth, Mars, and the asteroid belt. |
# | **Echo Gardens** | A cultural district with theaters, museums, and the **Lunar Symphony Hall**, where music is composed using the Moon’s natural resonances (the “lunar bells” of basaltic cliffs). |
#
# ---
#
# ### Everyday Life in Lunaris Prime
#
# - **Gravity:** Residents experience 1/6 g, so daily routines are adapted—exercise rigs, magnetic footwear, and “float‑commutes” (personal levitation pods) are common.
# - **Timekeeping:** The city follows **Lunar Standard Time (LST)**, a 24‑hour cycle synchronized with Earth’s UTC but offset by the Moon’s 27.3‑day orbital period for cultural festivals.
# - **Food:** Hydroponic wheat, algae‑based protein, and “Moon‑berries” (genetically‑engineered strawberries that thrive in low‑light conditions) dominate the diet, supplemented by occasional Earth imports.
# - **Transportation:** Residents zip around on maglev pods, personal hover‑skates, or the occasional rover for longer trips outside the dome.
# - **Culture:** Lunar holidays celebrate the **First Light** (the day the first human set foot on the Moon) and **Eclipse Night**, when Earth’s shadow passes over the city, plunging it into a spectacular, star‑filled darkness.
#
# ---
#
# ### Why It’s Called the “Capital”
#
# - **Political Center:** All lunar legislation, diplomacy, and inter‑planetary treaties are negotiated here.
# - **Economic Engine:** The Regolith Market and Neuro‑Forge make Lunaris Prime the financial heart of the Moon’s economy.
# - **Cultural Beacon:** From the Echo Gardens to the Solaris Dome’s gardens, the city is the primary source of lunar art, science, and identity.
# - **Symbolic Anchor:** Situated at the very point where Earth hangs directly overhead, Lunaris Prime embodies humanity’s bridge between its home planet and the new frontier.
#
# ---
#
# ### Fun Fact
#
# During a total lunar eclipse, the **Eclipse Port’s** reflective panels are angled to capture Earthshine, creating a natural “moon‑lit” glow that bathes the city in a soft, amber light. Residents gather in the Solaris Dome’s central plaza for the **“Silver Serenade,”** a nightly concert where musicians play instruments tuned to the subtle vibrations of the Moon’s crust—producing sounds no Earth‑bound ear has ever heard.
#
# ---
#
# **So, while the Moon may not have a capital in the real world—yet—imagine Lunaris Prime rising from the regolith, a shining testament to humanity’s reach for the stars.**

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=llm,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# Lunara

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=llm,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# **Name:** Lunaris Prime
#
# **Location:** Mare Imbrium, near the lunar equator – the central hub of the Moon’s terraformed megastructures.
#
# **Vibe:** Neon‑lit, bustling
#
# **Economy:** Lunar mineral extraction, orbital tourism, scientific research and development.

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=llm,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunaris Prime', location='Mare Imbrium, near the Shackleton crater at the lunar south pole', vibe='high-tech, scientific hub with a serene, otherworldly atmosphere', economy='lunar helium-3 mining, space tourism, research labs, and orbital trade')

# %%
response["structured_response"].name
# Out:
# 'Lunaris Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunaris Prime is a city located at Mare Imbrium, near the Shackleton crater at the lunar south pole
