# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="qwen3:14b",  
    model_provider="ollama",
    temperature=0
)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='The Moon does not have a capital city, as it is not a sovereign state and has no government, population, or infrastructure to support a capital. It is a natural satellite of Earth, and all human activities on the Moon (such as the Apollo missions) have been temporary and scientific in nature. \n\nIn science fiction or hypothetical scenarios, fictional "capitals" or lunar colonies may be imagined, but these are not real. As of now, the Moon remains unclaimed and uninhabited by any permanent human settlements.', additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-06T19:22:25.711108437Z', 'done': True, 'done_reason': 'stop', 'total_duration': 189130889333, 'load_duration': 111909166, 'prompt_eval_count': 18, 'prompt_eval_duration': 447831865, 'eval_count': 406, 'eval_duration': 188374022307, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019cc497-0143-7523-9e0b-916f72777839-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 406, 'total_tokens': 424})

# %%
print(response.content)
# Out:
# The Moon does not have a capital city, as it is not a sovereign state and has no government, population, or infrastructure to support a capital. It is a natural satellite of Earth, and all human activities on the Moon (such as the Apollo missions) have been temporary and scientific in nature.
#
# In science fiction or hypothetical scenarios, fictional "capitals" or lunar colonies may be imagined, but these are not real. As of now, the Moon remains unclaimed and uninhabited by any permanent human settlements.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'created_at': '2026-03-06T19:22:25.711108437Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 406,
#  'eval_duration': 188374022307,
#  'load_duration': 111909166,
#  'logprobs': None,
#  'model': 'qwen3:14b',
#  'model_name': 'qwen3:14b',
#  'model_provider': 'ollama',
#  'prompt_eval_count': 18,
#  'prompt_eval_duration': 447831865,
#  'total_duration': 189130889333}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="qwen3:14b",
    model_provider="ollama", 
    temperature=1.0)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon does not have a capital city. As Earth's only natural satellite, the Moon is not home to any countries, governments, or permanent human settlements (as of now). While there have been proposals and fictional depictions of lunar bases or colonies in science fiction (e.g., in novels, films, or speculative concepts), no such entity exists in reality.
#
# **Key points:**
# 1. **No official capital**: The Moon is not sovereign territory and is governed by international agreements like the 1967 Outer Space Treaty, which prohibits any nation from claiming sovereignty over celestial bodies.
# 2. **Current status**: Human presence on the Moon has been limited to brief visits by astronauts during the Apollo missions (1969–1972). Future plans, such as NASA's Artemis program, aim to establish sustainable lunar exploration, but no permanent capital or city exists yet.
# 3. **Fictional references**: In science fiction, lunar capitals or cities are sometimes imagined (e.g., in *Star Trek* or *The Moon Is a Harsh Mistress*), but these remain speculative.
#
# So, the Moon's "capital" is... well, there isn't one! 🌕

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(
    model="moonshotai/kimi-k2-instruct-0905",
    model_provider="groq",
    temperature=0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
model = init_chat_model(
    model="gemini-1.5-flash",
    model_provider="google_genai",
    temperature=0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
model = init_chat_model(model="gpt-oss:20b",  model_provider="ollama")

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)

# %%
print(response['messages'][-1].content)

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)

# %%
print(response['messages'][-1].content)

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
