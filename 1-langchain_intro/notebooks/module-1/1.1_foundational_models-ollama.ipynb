# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="qwen3:14b",  
    model_provider="ollama",
    temperature=0
)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='The Moon does not have a capital city, as it is not a sovereign state and has no government or political structure. It is a natural satellite of Earth, and no nation or entity has officially claimed sovereignty over it (as stipulated by international treaties like the 1967 Outer Space Treaty). \n\nIn fiction, some stories or media may imagine lunar cities or capitals (e.g., in science fiction novels or films), but these are purely speculative and not based on reality. As of now, the Moon remains unpopulated and without any formal administrative divisions. 🌕', additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-06T19:52:10.03418747Z', 'done': True, 'done_reason': 'stop', 'total_duration': 212415438121, 'load_duration': 30414656447, 'prompt_eval_count': 18, 'prompt_eval_duration': 4183609886, 'eval_count': 390, 'eval_duration': 177561566400, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019cc4b1-dfcb-7f02-9de9-702e10e96038-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 390, 'total_tokens': 408})

# %%
print(response.content)
# Out:
# The Moon does not have a capital city, as it is not a sovereign state and has no government or political structure. It is a natural satellite of Earth, and no nation or entity has officially claimed sovereignty over it (as stipulated by international treaties like the 1967 Outer Space Treaty).
#
# In fiction, some stories or media may imagine lunar cities or capitals (e.g., in science fiction novels or films), but these are purely speculative and not based on reality. As of now, the Moon remains unpopulated and without any formal administrative divisions. 🌕

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'created_at': '2026-03-06T19:52:10.03418747Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 390,
#  'eval_duration': 177561566400,
#  'load_duration': 30414656447,
#  'logprobs': None,
#  'model': 'qwen3:14b',
#  'model_name': 'qwen3:14b',
#  'model_provider': 'ollama',
#  'prompt_eval_count': 18,
#  'prompt_eval_duration': 4183609886,
#  'total_duration': 212415438121}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="qwen3:14b",
    model_provider="ollama", 
    temperature=1.0)

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(
    model="moonshotai/kimi-k2-instruct-0905",
    model_provider="groq",
    temperature=0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn’t have a capital—no government, no cities, no flags. Just craters, dust, and a lot of quiet.

# %% [markdown]
# ## Initialising and invoking an agent

# %%
model = init_chat_model(
    model="qwen3:14b",
    model_provider="ollama", 
    temperature=0)

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='2dc36417-c532-4eb2-92c1-77c7acee5bc1'),
#               AIMessage(content='The Moon does not have a capital city, as it is not a sovereign state and has no government or political structure. It is a natural satellite of Earth, and no nation or entity has officially claimed sovereignty over it (as stipulated by international treaties like the 1967 Outer Space Treaty). \n\nIn fiction, some stories or media may imagine lunar cities or capitals (e.g., in science fiction novels or films), but these are purely speculative and not based on reality. As of now, the Moon remains unpopulated and without any formal administrative divisions. 🌕', additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-06T20:12:26.602010088Z', 'done': True, 'done_reason': 'stop', 'total_duration': 212544020107, 'load_duration': 30803315782, 'prompt_eval_count': 18, 'prompt_eval_duration': 4284334992, 'eval_count': 390, 'eval_duration': 177243143113, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019cc4c4-7026-77d2-b8cc-6808dcef96af-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 390, 'total_tokens': 408})]}

# %%
print(response['messages'][-1].content)
# Out:
# The Moon does not have a capital city, as it is not a sovereign state and has no government or political structure. It is a natural satellite of Earth, and no nation or entity has officially claimed sovereignty over it (as stipulated by international treaties like the 1967 Outer Space Treaty).
#
# In fiction, some stories or media may imagine lunar cities or capitals (e.g., in science fiction novels or films), but these are purely speculative and not based on reality. As of now, the Moon remains unpopulated and without any formal administrative divisions. 🌕

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='1371431c-f071-4a2d-a87f-87c55cfbc491'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='85ecdd34-5f3d-4c4e-ab27-750ed6f81c72', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='9bfa4b39-fc22-456f-ac4e-1284324795e8'),
#               AIMessage(content='Luna City is not a real place—it’s a fictional concept that appears in various works of science fiction, often as a lunar colony or base. Here’s a breakdown of its portrayals and the broader context of lunar settlements in fiction and real-world planning:\n\n---\n\n### **Fictional Depictions of "Luna City"**\n1. **"Moon" (2009 film)**:  \n   - The film *Moon* (starring Sam Rockwell) features a lunar mining base called *Lunar Base One*, not "Luna City," but it’s a common misconception. The base is depicted as a remote facility on the Moon, highlighting themes of isolation and corporate exploitation.\n\n2. **"Star Trek" Universe**:  \n   - In some *Star Trek* stories, "Luna City" is a lunar colony established during the 21st or 22nd century. It often serves as a hub for Earth-Moon trade or a political entity in a future where humanity has expanded beyond Earth.\n\n3. **Video Games and Novels**:  \n   - In the 2018 game *Luna City*, players simulate managing a lunar colony, focusing on resource management and survival.  \n   - In novels like *The Moon is a Harsh Mistress* by Robert A. Heinlein, lunar settlements are central to the plot, though the term "Luna City" isn’t used.\n\n---\n\n### **Real-World Lunar Settlements (Not Yet Established)**\nWhile no "capital" of the Moon exists today, space agencies and private companies are actively planning for future lunar bases. Key initiatives include:\n- **NASA’s Artemis Program**: Aims to establish a sustainable human presence on the Moon by the 2030s, including a lunar base called the **Artemis Base Camp**.\n- **China’s Lunar Exploration Program**: Plans to build a lunar research station by the 2030s.\n- **Private Sector Efforts**: Companies like SpaceX and Blue Origin are developing technologies for lunar colonization, though no cities exist yet.\n\n---\n\n### **Why "Luna City"?**\nThe term "Luna City" is often used in fiction to evoke a sense of a futuristic, self-sustaining human settlement on the Moon. It reflects humanity’s long-standing fascination with lunar colonization and the challenges of living in space.\n\nIf you’re curious about specific fictional works or real-world lunar plans, feel free to ask! 🌕', additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-06T20:19:49.795456377Z', 'done': True, 'done_reason': 'stop', 'total_duration': 409070270707, 'load_duration': 162254086, 'prompt_eval_count': 45, 'prompt_eval_duration': 7073155578, 'eval_count': 831, 'eval_duration': 401411885774, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019cc4c8-33ac-7160-91aa-736ee430e41f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 45, 'output_tokens': 831, 'total_tokens': 876})]}

# %%
print(response['messages'][-1].content)
# Out:
# Luna City is not a real place—it’s a fictional concept that appears in various works of science fiction, often as a lunar colony or base. Here’s a breakdown of its portrayals and the broader context of lunar settlements in fiction and real-world planning:
#
# ---
#
# ### **Fictional Depictions of "Luna City"**
# 1. **"Moon" (2009 film)**:
#    - The film *Moon* (starring Sam Rockwell) features a lunar mining base called *Lunar Base One*, not "Luna City," but it’s a common misconception. The base is depicted as a remote facility on the Moon, highlighting themes of isolation and corporate exploitation.
#
# 2. **"Star Trek" Universe**:
#    - In some *Star Trek* stories, "Luna City" is a lunar colony established during the 21st or 22nd century. It often serves as a hub for Earth-Moon trade or a political entity in a future where humanity has expanded beyond Earth.
#
# 3. **Video Games and Novels**:
#    - In the 2018 game *Luna City*, players simulate managing a lunar colony, focusing on resource management and survival.
#    - In novels like *The Moon is a Harsh Mistress* by Robert A. Heinlein, lunar settlements are central to the plot, though the term "Luna City" isn’t used.
#
# ---
#
# ### **Real-World Lunar Settlements (Not Yet Established)**
# While no "capital" of the Moon exists today, space agencies and private companies are actively planning for future lunar bases. Key initiatives include:
# - **NASA’s Artemis Program**: Aims to establish a sustainable human presence on the Moon by the 2030s, including a lunar base called the **Artemis Base Camp**.
# - **China’s Lunar Exploration Program**: Plans to build a lunar research station by the 2030s.
# - **Private Sector Efforts**: Companies like SpaceX and Blue Origin are developing technologies for lunar colonization, though no cities exist yet.
#
# ---
#
# ### **Why "Luna City"?**
# The term "Luna City" is often used in fiction to evoke a sense of a futuristic, self-sustaining human settlement on the Moon. It reflects humanity’s long-standing fascination with lunar colonization and the challenges of living in space.
#
# If you’re curious about specific fictional works or real-world lunar plans, feel free to ask! 🌕

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City, as a specific named capital of the Moon, does not currently exist in reality. However, the concept of a lunar city—often referred to in science fiction, speculative engineering, and space exploration discussions—captures the imagination of what future human settlements on the Moon might look like. Here's an overview of the idea, its context, and related concepts:
#
# ---
#
# ### **1. Fictional and Conceptual Depictions of "Luna City"**
# While there is no official "Luna City" on the Moon, the name has appeared in various fictional works, such as:
# - **Science Fiction Literature**: In some novels, "Luna City" is used as a fictional settlement or capital of a lunar colony. For example, in the *Luna* series by Dan Simmons, the Moon is a key setting with complex political and social structures, though the specific name "Luna City" may not be used.
# - **Games and Media**: Video games, films, and TV shows sometimes feature lunar cities as hubs for space exploration or conflict. These are typically speculative and not tied to real-world plans.
#
# ---
#
# ### **2. Real-World Lunar Settlement Concepts**
# While no city exists yet, space agencies and private companies are actively exploring the feasibility of lunar bases. These concepts often include elements that could be described as "Luna City" in a hypothetical future:
# - **NASA's Artemis Program**: Aims to establish a sustainable human presence on the Moon by the 2030s, including a lunar base called the **Artemis Base Camp**. This could evolve into a more permanent settlement.
# - **International Lunar Research Station (ILRS)**: A collaboration between China and Russia, envisioning a research station on the Moon by the 2030s.
# - **Private Initiatives**: Companies like SpaceX and Blue Origin have proposed long-term goals for lunar colonization, though no cities are currently under construction.
#
# ---
#
# ### **3. Challenges of Building a Lunar City**
# Creating a city on the Moon would require overcoming significant technical and environmental challenges:
# - **Radiation**: The Moon lacks a magnetic field and thick atmosphere, exposing settlers to cosmic and solar radiation. Solutions might include underground habitats or radiation-shielded domes.
# - **Temperature Extremes**: Lunar temperatures swing from -173°C (-280°F) at night to 127°C (260°F) during the day. Insulated habitats and thermal regulation systems would be essential.
# - **Life Support**: Oxygen, water, and food would need to be sourced from lunar resources (e.g., extracting water from ice in permanently shadowed craters) or transported from Earth.
# - **Transportation**: Establishing a supply chain for materials and personnel would require advanced spacecraft and infrastructure.
#
# ---
#
# ### **4. Potential Features of a Lunar City**
# If a city like "Luna City" were to be built, it might include:
# - **Modular Habitats**: Pressurized modules for living, working, and research, possibly 3D-printed using lunar regolith.
# - **Solar Power**: The Moon's long days (14 Earth days) and lack of weather make solar energy a viable power source.
# - **Agriculture**: Hydroponic or aeroponic farms to grow food, possibly in controlled environments.
# - **Research Facilities**: For studying the Moon's geology, astronomy, and testing technologies for deep-space missions.
# - **Economic Zones**: Mining for rare minerals (e.g., helium-3, titanium) or manufacturing in microgravity.
#
# ---
#
# ### **5. Cultural and Historical Context**
# - The name "Luna" (Latin for "Moon") has been used in various contexts, including:
#   - **Luna City, Florida**: A real town in the U.S. named after the Moon, though unrelated to space exploration.
#   - **Luna (spacecraft)**: A Soviet lunar probe in the 1960s.
#   - **Lunar Colonization in Science Fiction**: From H.G. Wells' *The First Men in the Moon* (1901) to modern works like *The Expanse* series.
#
# ---
#
# ### **6. Future Prospects**
# While a "Luna City" remains a distant vision, the next few decades could see the first small lunar outposts. These might eventually grow into larger settlements, potentially evolving into cities. Key milestones would include:
# - **Establishing a permanent human presence** by the 2030s–2040s.
# - **Developing self-sufficiency** through in-situ resource utilization (ISRU).
# - **International collaboration** to share costs and expertise.
#
# ---
#
# ### **Conclusion**
# "Luna City" is not a real place but a symbolic representation of humanity's aspirations for lunar colonization. While current efforts focus on small bases and research stations, the idea of a thriving lunar capital remains a compelling vision for the future of space exploration. As technology advances and global interest in the Moon grows, the dream of a "Luna City" may one day become reality.
