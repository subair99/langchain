# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-oss:20b",  model_provider="ollama")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content="The Moon has no capital—it's not a country, just Earth's natural satellite, so it has no government or capital city.", additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2026-02-21T21:33:22.551519279Z', 'done': True, 'done_reason': 'stop', 'total_duration': 93257903062, 'load_duration': 41959308550, 'prompt_eval_count': 74, 'prompt_eval_duration': 6405928516, 'eval_count': 207, 'eval_duration': 44613848041, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019c821d-b371-7130-86b0-e6d2143f7949-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 74, 'output_tokens': 207, 'total_tokens': 281})

# %%
print(response.content)
# Out:
# The Moon has no capital—it's not a country, just Earth's natural satellite, so it has no government or capital city.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'created_at': '2026-02-21T21:33:22.551519279Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 207,
#  'eval_duration': 44613848041,
#  'load_duration': 41959308550,
#  'logprobs': None,
#  'model': 'gpt-oss:20b',
#  'model_name': 'gpt-oss:20b',
#  'model_provider': 'ollama',
#  'prompt_eval_count': 74,
#  'prompt_eval_duration': 6405928516,
#  'total_duration': 93257903062}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(model="gpt-oss:20b",  model_provider="ollama", temperature=1.0)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn’t have a capital.  It’s an uninhabited celestial body with no government, administrative center, or official “capital city.”  Any references to a lunar capital are purely fictional or hypothetical (e.g., in sci‑fi stories or speculative future plans for lunar colonies).

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="qwen3:14b",  model_provider="ollama")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon does not have a capital city, as it is not a sovereign state and has no government, population, or cities in the traditional sense. According to international agreements like the **Outer Space Treaty (1967)**, no nation can claim sovereignty over the Moon or any other celestial body.
#
# However, there are some symbolic or fictional references:
# - In science fiction, the concept of a "lunar capital" sometimes appears (e.g., in stories about future lunar colonies).
# - The name **"Selene"** (after the Greek moon goddess) is occasionally used in speculative contexts for hypothetical lunar settlements or governance structures, but it is not an official designation.
#
# In reality, the Moon remains a shared resource under international law, with exploration and use governed by principles of peaceful cooperation and non-claiming of territory. 🌕

# %% [markdown]
# ## Initialising and invoking an agent

# %%
model = init_chat_model(model="gpt-oss:20b",  model_provider="ollama")

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='f7e90066-a451-4e84-8fb9-db2a71f506c1'),
#               AIMessage(content='The Moon doesn’t have a capital in the way a country does.  \nIt isn’t a sovereign state, so there is no government or administrative center that would be called a “capital.”  \n\nIn science‑fiction and speculative planning, people sometimes imagine a “capital” for a future lunar colony—perhaps a hub near the Moon’s equator or a flagship base on the near side—but those are just concepts, not actual political entities. So, for real‑world facts: **the Moon has no capital.**', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2026-02-21T21:41:44.228596772Z', 'done': True, 'done_reason': 'stop', 'total_duration': 119807635970, 'load_duration': 42602588244, 'prompt_eval_count': 74, 'prompt_eval_duration': 6433579333, 'eval_count': 333, 'eval_duration': 70437517661, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019c8224-eea1-7c31-b7e2-a8272dd5bee2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 74, 'output_tokens': 333, 'total_tokens': 407})]}

# %%
print(response['messages'][-1].content)
# Out:
# The Moon doesn’t have a capital in the way a country does.
# It isn’t a sovereign state, so there is no government or administrative center that would be called a “capital.”
#
# In science‑fiction and speculative planning, people sometimes imagine a “capital” for a future lunar colony—perhaps a hub near the Moon’s equator or a flagship base on the near side—but those are just concepts, not actual political entities. So, for real‑world facts: **the Moon has no capital.**

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='6c284bfc-2e01-432d-8b0e-7dd910f85123'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='ea9ea2de-d090-43ea-a61b-5c169d317620', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='c89ef1b3-fa3a-4054-a93e-f0ee4ecf90d3'),
#               AIMessage(content='There isn’t actually a “capital” on the Moon—no city, no government, no official seat of power.\u202fThe Moon is still an uninhabited celestial body, and any mention of a Luna City is purely speculative or fictional.  \n\nBelow, I’ll split the answer into two parts:  \n\n| What’s true | What’s hypothetical |\n|-------------|---------------------|\n| *The Moon has no human settlement yet.* | *Luna City is a concept often used in science‑fiction and forward‑thinking plans for lunar colonization.* |\n| *NASA’s Artemis program aims to return humans to the Moon by the late 2020s and establish a sustainable presence by the 2030s.* | *If a permanent lunar capital were built, it would probably be centered around the equatorial “Canadiana” region or the “Aureole” near the lunar South Pole, where sunlight and water‑ice are abundant.* |\n| *International Space Agency (ESA), the Japanese space agency (JAXA), the Canadian Space Agency (CSA), and private companies like SpaceX, Blue Origin, and others are all interested in lunar habitats.* | *A Luna City might feature domed habitats, regolith‑based building materials, nuclear or solar power, hydroponic farms, and a network of underground tunnels to shield residents from radiation.* |\n\n---\n\n### What a “Luna City” Might Look Like (Imagined)\n\n1. **Location**  \n   *Equatorial Band:* Provides constant sunlight (except at the terminator) and easier communication with Earth.  \n   *Polar Regions:* Access to water‑ice deposits at permanently shadowed craters (essential for life support and fuel).  \n\n2. **Infrastructure**  \n   *Regolith‑based construction* (using the Moon’s own soil to make bricks or 3‑D printed regolith blocks).  \n   *Air‑lock domes* that keep Earth‑atmosphere pressure and temperature inside while shielding the outside from micrometeorites.  \n   *Power:* A combination of high‑efficiency solar panels (using concentrators to handle the 14‑day “night”) and small nuclear reactors for continuous energy.  \n   *Water and Life Support:* Regolith‑based extraction of water‑ice, closed‑loop recycling of CO₂ and waste, hydroponic farms, and algae bioreactors.  \n   *Transportation:* Rovers, lunar elevators for cargo from Earth, and eventually a lunar “high‑way” system of guided pathways for rapid movement between zones.  \n\n3. **Governance**  \n   Since no nation currently has sovereignty over the Moon (the Outer Space Treaty prohibits national claims), a Luna City would likely be governed by an international consortium—perhaps an extension of the International Space Station (ISS) governance model or a new “Lunar Charter” negotiated by spacefaring nations and private stakeholders.  \n\n4. **Social and Cultural Life**  \n   Imagine a small, tightly‑knit community of 1,000–5,000 people. Public spaces would be dome‑capped parks, research labs, museums of Earth history, and a “Lunar Library” that houses both scientific data and cultural artifacts. Entertainment would rely heavily on virtual reality and community projects.  \n\n5. **Challenges**  \n   *Radiation*: Without a magnetic field or thick atmosphere, shielding is critical.  \n   *Psychology*: Isolation, limited gravity (0.165\u202fg), and a stark landscape can affect mental health.  \n   *Economics*: The cost of launch, construction, and resupply is enormous—necessitating high‑value industries (e.g., high‑grade solar power, rare‑earth mining, scientific research).  \n\n---\n\n### Current Reality vs. Future Possibility\n\n| Aspect | Current Reality | Near‑Future Possibility (2030s‑2050s) |\n|--------|-----------------|---------------------------------------|\n| **Population** | 0 | 100–1,000 (initially) |\n| **Infrastructure** | Testing habitats on the ISS, robotic missions to the Moon | 3‑D printed habitats, regolith extraction, solar arrays, micro‑gravity farms |\n| **Governance** | Space Treaty (no sovereign claims) | International Lunar Charter, possibly a lunar “government” or “municipality ...

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t actually a “capital” on the Moon—no city, no government, no official seat of power. The Moon is still an uninhabited celestial body, and any mention of a Luna City is purely speculative or fictional.
#
# Below, I’ll split the answer into two parts:
#
# | What’s true | What’s hypothetical |
# |-------------|---------------------|
# | *The Moon has no human settlement yet.* | *Luna City is a concept often used in science‑fiction and forward‑thinking plans for lunar colonization.* |
# | *NASA’s Artemis program aims to return humans to the Moon by the late 2020s and establish a sustainable presence by the 2030s.* | *If a permanent lunar capital were built, it would probably be centered around the equatorial “Canadiana” region or the “Aureole” near the lunar South Pole, where sunlight and water‑ice are abundant.* |
# | *International Space Agency (ESA), the Japanese space agency (JAXA), the Canadian Space Agency (CSA), and private companies like SpaceX, Blue Origin, and others are all interested in lunar habitats.* | *A Luna City might feature domed habitats, regolith‑based building materials, nuclear or solar power, hydroponic farms, and a network of underground tunnels to shield residents from radiation.* |
#
# ---
#
# ### What a “Luna City” Might Look Like (Imagined)
#
# 1. **Location**
#    *Equatorial Band:* Provides constant sunlight (except at the terminator) and easier communication with Earth.
#    *Polar Regions:* Access to water‑ice deposits at permanently shadowed craters (essential for life support and fuel).
#
# 2. **Infrastructure**
#    *Regolith‑based construction* (using the Moon’s own soil to make bricks or 3‑D printed regolith blocks).
#    *Air‑lock domes* that keep Earth‑atmosphere pressure and temperature inside while shielding the outside from micrometeorites.
#    *Power:* A combination of high‑efficiency solar panels (using concentrators to handle the 14‑day “night”) and small nuclear reactors for continuous energy.
#    *Water and Life Support:* Regolith‑based extraction of water‑ice, closed‑loop recycling of CO₂ and waste, hydroponic farms, and algae bioreactors.
#    *Transportation:* Rovers, lunar elevators for cargo from Earth, and eventually a lunar “high‑way” system of guided pathways for rapid movement between zones.
#
# 3. **Governance**
#    Since no nation currently has sovereignty over the Moon (the Outer Space Treaty prohibits national claims), a Luna City would likely be governed by an international consortium—perhaps an extension of the International Space Station (ISS) governance model or a new “Lunar Charter” negotiated by spacefaring nations and private stakeholders.
#
# 4. **Social and Cultural Life**
#    Imagine a small, tightly‑knit community of 1,000–5,000 people. Public spaces would be dome‑capped parks, research labs, museums of Earth history, and a “Lunar Library” that houses both scientific data and cultural artifacts. Entertainment would rely heavily on virtual reality and community projects.
#
# 5. **Challenges**
#    *Radiation*: Without a magnetic field or thick atmosphere, shielding is critical.
#    *Psychology*: Isolation, limited gravity (0.165 g), and a stark landscape can affect mental health.
#    *Economics*: The cost of launch, construction, and resupply is enormous—necessitating high‑value industries (e.g., high‑grade solar power, rare‑earth mining, scientific research).
#
# ---
#
# ### Current Reality vs. Future Possibility
#
# | Aspect | Current Reality | Near‑Future Possibility (2030s‑2050s) |
# |--------|-----------------|---------------------------------------|
# | **Population** | 0 | 100–1,000 (initially) |
# | **Infrastructure** | Testing habitats on the ISS, robotic missions to the Moon | 3‑D printed habitats, regolith extraction, solar arrays, micro‑gravity farms |
# | **Governance** | Space Treaty (no sovereign claims) | International Lunar Charter, possibly a lunar “government” or “municipality” |
# | **Economy** | None | Mining of water‑ice, regolith, potential for high‑value manufacturing (e.g., satellite components) |
#
# ---
#
# ### Bottom Line
#
# - **There is no official “capital” on the Moon.**
# - **Luna City is a useful thought experiment** that captures many of the engineering, political, and social questions that will need to be solved before humans can live permanently on the Moon.
#
# If you’re interested in the science‑fiction side, you can read works like *“The Moon is a Harsh Mistress”* by Robert A. Heinlein, *“Red Mars”* by Kim Stanley Robinson (which includes a section on the Moon), or the “Lunar Base” series by various authors. In the real world, you’ll find the most detailed and up‑to‑date plans in the NASA Artemis roadmap, ESA’s Lunar Gateway strategy, and the upcoming private‑sector missions (SpaceX’s Starship, Blue Origin’s Blue Moon).

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# ## Luna City – Capital of the Moon
#
# *(All details are based on the collective vision of the Lunar‑Era, as presented in the “Lunar‑Capital Encyclopedia” published by the International Lunar Authority in 2081. The facts are a blend of real lunar science and the plausible technological trajectory expected between 2035 and 2090.)*
#
# ---
#
# ### 1. Quick Facts
#
# | Item | Detail |
# |------|--------|
# | **Official name** | Luna City (also called the “Capital of the Moon”) |
# | **Location** | Mare Tranquillitatis, near the 0° E meridian, inside a shallow basaltic basin (≈ 200 m deep). |
# | **Surface area** | ~ 15 km² (habitat ring + core complex + satellite outposts). |
# | **Population** | ~ 30 000 (as of 2079). |
# | **Governance** | Lunar Authority‑City Council (LACC) – a democratically elected body; Mayor + nine councillors; advisory committees on science, commerce, and culture. |
# | **Official languages** | English (primary), plus Mandarin, Russian, Spanish, and a new “Lunar” lingua‑franca based on English‑German phonetics. |
# | **Time zone** | Lunar Standard Time (LST), 00:00 LST = 00:00 UTC + 0 h 3 min. |
# | **Key industries** | Helium‑3 mining, solar‑electric power, micro‑gravity manufacturing (ultralight alloys, photonic crystals), research & development, space‑tourism. |
# | **Transportation** | Lunar rovers, tethered sky‑ships (low‑orbit airships), the “Lunar Gateway” orbital hub, suborbital transport to Earth (Mars‑class “Luna‑Express”). |
# | **Major institutions** | Lunar Academy of Sciences, Luna Museum of History, Luna Space‑Health Institute, International Lunar Academy (ILA). |
# | **Climate** | Temperatures from −120 °C at night to +30 °C at noon; 0.17 g gravity; 1 % Earth‑atmospheric pressure in controlled habitats. |
#
# ---
#
# ### 2. A Brief History
#
# | Year | Milestone |
# |------|-----------|
# | **1969** | First Apollo 11 footfall on the Moon, but no permanent settlement. |
# | **2034** | International Lunar Initiative (ILI) established, pooling resources from NASA, ESA, CNSA, Roscosmos, ISRO, JAXA, and several private companies (SpaceX, Blue Origin, etc.). |
# | **2036–2040** | Construction of the *Lunar Gateway* – a small orbital station around the near side, serving as a staging ground for surface operations. |
# | **2043** | *Luna‑Base 1* operational, a modular habitat ring built using in‑situ resource utilization (ISRU) and additive manufacturing. |
# | **2050** | First city‑scale infrastructure projects begin: *Regolith Printing Plant*, *Helium‑3 Extraction Facility*, and *Solar‑Tower Array*. |
# | **2053** | Luna City receives provisional status from the ILI, becoming the de‑facto capital of the Moon’s inter‑governmental authority. |
# | **2055** | Population surpasses 10 000. The *Lunar Authority* is formally established, with Luna City as its seat. |
# | **2065** | Construction of the *Lunar Parliament* and *Supreme Court* on the central “Capitol” plaza. |
# | **2070** | First commercial lunar tourism operators launch flights to Luna City. |
# | **2075** | Lunar City celebrates its 20th anniversary; “Moonrise Festival” attracts thousands of Earth‑based livestream viewers. |
# | **2079** | Population peaks at ~30 000; new expansion ring built to accommodate scientific and residential growth. |
#
# ---
#
# ### 3. Geography & Architecture
#
# **Location**
# - Mare Tranquillitatis was chosen for its basaltic, relatively flat terrain and its proximity to large deposits of water ice at depths of 40–50 m.
# - The city sits within a natural shallow basin, which reduces the need for extensive excavation and allows the construction of a “ring‑habitat” structure that embraces the central water‑ice extraction well.
#
# **Structural Design**
# - **Habitat Ring**: 8 km in circumference, 300 m wide, segmented into 12 modules (each ~ 700 m² per module). Modules are made from *regolith‑sintered composites* (a mix of lunar soil and binder that, when sintered, forms a dense, load‑bearing material).
# - **Central Core**: Houses the *Lunar Parliament*, *Supreme Court*, *City Hall*, *Cultural Center*, *Hospital*, and *main transport hub*. Built in a dome of 200 m radius, lined with titanium alloy and a multi‑layer thermal shield.
# - **Sub‑Modules**: Surrounding the core are industrial zones (Helium‑3 extraction, solar array assembly, biotech labs), residential quarters, hydroponic farms, and recreational parks.
# - **Radiation Shielding**: The outer layer of the habitat ring is a 15 cm regolith shell, supplemented by *active magnetic shielding* (thin superconducting coils generating a local magnetic field to deflect charged particles).
#
# **Urban Planning**
# - Streets are largely underground to protect inhabitants from micrometeorite impacts.
# - The *Sun Path Corridor* – a 200 m wide boulevard lined with solar cells that doubles as an energy generator.
# - Parks are designed as “gravity‑simulated” zones: a mix of vertical gardens, floating sculptures, and low‑gravity sports fields.
#
# ---
#
# ### 4. Governance & Politics
#
# **The Lunar Authority‑City Council (LACC)**
# - Elected every 4 years by the city’s citizens; 9 councillors plus a mayor.
# - The mayor is elected by the council (a parliamentary system).
# - LACC also serves as the liaison with the *International Lunar Authority* (ILA), which governs the entire lunar territory.
#
# **Legal Framework**
# - The *Lunar Charter* (signed in 2047) sets the legal basis: sovereignty is shared among signatory nations; Luna City is a *free city-state* under the ILA’s jurisdiction.
# - *The Lunar Code of Conduct* addresses property, commerce, environmental protection, and citizen rights.
#
# **Diplomatic Role**
# - Luna City hosts the *Lunar Summit* – an annual gathering where Earth governments negotiate treaties on mining, research, and future colonization of Mars.
# - The *Interplanetary Liaison Office* handles communications with Mars colonies and asteroid mining companies.
#
# ---
#
# ### 5. Economy
#
# | Sector | Key Activities | Major Enterprises |
# |--------|----------------|-------------------|
# | **Helium‑3 Mining** | Extraction via heated regolith, followed by separation and cryogenic storage. | Helium‑3 Extractors Inc., Lunar Resource Group |
# | **Solar Power** | Massive arrays on the outskirts, delivering electricity to Earth via laser‑beam transmission or spacecraft. | SolLuna Energy, Lunar Grid |
# | **Micro‑gravity Manufacturing** | Production of lightweight aerospace components, photonic crystals, and biomedical materials. | Gravitech, LUNA Manufacturing |
# | **Research & Development** | Fundamental physics, planetary science, bio‑engineering. | Lunar Academy, Institute for Lunar Biosystems |
# | **Space Tourism** | Low‑gravity experience flights, “moonwalk” packages, educational tours. | LunaVoyage, SpaceLuna Resorts |
# | **Education & Training** | Lunar Academy offers degrees in *Astro‑Engineering*, *Space‑Law*, and *Regolith Science*. | ILA, Lunar Academy |
# | **Agriculture** | Hydroponic farms producing fresh produce for residents and export. | LunaGrow, Martian Export Agency |
#
# - **Budget**: In 2078, Luna City’s annual budget was approximately USD 4 billion, mostly funded by export of Helium‑3, solar power contracts, and tourism fees.
#
# ---
#
# ### 6. Population & Society
#
# **Demographics (2025‑2079)**
# - 30 % Earth citizens (diverse nationalities).
# - 50 % private‑sector employees (companies that built or operate Luna City).
# - 10 % scientific community (researchers, students).
# - 10 % local administrators and support staff.
#
# **Daily Life**
# - A 14‑hour “lunar day” (approximately 25.9 h Earth time). The city’s schedule is divided into **Lunar Hours** (LH).
# - **Work**: 2 LH shift cycles (morning: 0–7 LH; evening: 7–14 LH).
# - **Sleep**: 5 LH, usually during the night segment.
# - **Recreation**: 4 LH, including sports (Lunar Rugby, Zero‑G Basketball), cultural events, and communal meals.
#
# **Health & Wellness**
# - Chronic bone density loss is mitigated by mechanical counter‑measures (resistance training, pulsatile centrifuge pods).
# - The *Lunar Health Institute* monitors cardiovascular, neurological, and psychological health; it also serves as the primary medical center.
#
# **Education**
# - Primary and secondary schools adopt a bilingual curriculum (English & Lunar).
# - The *Lunar Academy* offers degrees from Bachelor to Ph.D. level; many programs are online with Earth students participating through virtual reality interfaces.
#
# ---
#
# ### 7. Culture & Lifestyle
#
# | Aspect | Details |
# |--------|---------|
# | **Festivals** | *Moonrise* (annual celebration of Luna City’s founding); *Regolith Day* (featuring rock‑hiding competitions); *Solar Eclipse Festival* (celebrating the 2027 lunar eclipse). |
# | **Arts** | The *Luna Museum of History* houses artefacts from Apollo missions and modern lunar art. The *Lunar Theater* performs in a dome‑shaped auditorium with acoustics tuned for low‑gravity. |
# | **Cuisine** | Fusion cuisine using hydroponic herbs, regolith‑grown lentils, and imported Earth staples. Popular dishes: “Moon‑Mush” (regolith‑cooked mushroom risotto). |
# | **Sports** | *Zero‑G Basketball*, *Lunar Tug‑of‑War*, *Regolith Polo* (on rails). |
# | **Music** | *Helium‑3 Opera*, a performance where singers use special voice‑modulation devices to emulate the lunar atmosphere. |
# | **Fashion** | Low‑gravity suits that balance mobility and thermal control. Designers like *LunarThreads* create “float‑wear” for residents. |
#
# ---
#
# ### 8. Science & Innovation
#
# **Key Research Areas**
# - *Regolith Utilization*: converting raw lunar soil into building materials, batteries, and life‑support consumables.
# - *Helium‑3 Fusion*: prototypes of plasma confinement devices have reached *10%* fusion efficiency (200 t in 2085).
# - *Astrobiology*: studying extremophiles in basaltic samples to understand potential life on Mars and Europa.
# - *Space‑Health Medicine*: developing counter‑measures for bone loss, radiation sickness, and psychosocial health in confined environments.
#
# **Notable Projects**
# - **The Lunar Sieve**: an automated regolith‑sorting machine that extracts water ice with 95 % efficiency.
# - **Project Solar‑Belt**: a ring of solar panels 50 km long that beams power back to Earth via laser pulses.
# - **Gravity‑Lab**: a portable centrifuge pod allowing experiments at adjustable “g‑levels” from 0.1 g to 1.0 g.
#
# ---
#
# ### 9. Transportation & Infrastructure
#
# | Mode | Description |
# |------|-------------|
# | **Lunar Rovers** | Autonomous and man‑tended vehicles built from regolith‑composite frames; speeds up to 6 km/h. |
# | **Sky‑Ships** | 3‑m² tethered airships that ride thermal currents for intra‑city transport (used for quick trips across the ring). |
# | **Orbital Hubs** | *Lunar Gateway* (near‑side orbit), *Luna‑Express* (suborbital launch and landing to Earth). |
# | **Inter‑city Link** | The *Lunar Express Train* (maglev in a vacuum tunnel) connects Luna City to other lunar outposts like *Mare Imbrium West* (≈ 500 km). |
# | **Public Transit** | Sub‑orbital shuttle services that circulate every 30 minutes during the day; each shuttle holds 120 passengers. |
#
# **Energy & Water**
# - Solar arrays cover 30 km², providing 70 % of the city’s electricity needs.
# - Water is extracted from ice deposits (≈ 10,000 t annually) and recycled through the *Water‑Recycling Plant* with 99.9 % recovery.
#
# ---
#
# ### 10. Challenges & Sustainability
#
# | Issue | Current Measures | Future Goals |
# |-------|------------------|--------------|
# | **Radiation** | Magnetic shielding + regolith cover | Develop advanced active shielding; integrate nanomaterial layers. |
# | **Dust** | Electrostatic repellents + sealed living areas | Implement dust‑free entryways; develop nanofilters. |
# | **Thermal Extremes** | Thermal blankets + heat‑exchange loops | Use phase‑change materials in habitat walls. |
# | **Health** | Counter‑measures (exercise, pharmacology) | Develop bone‑growth enhancers; research micro‑gravity pharmacology. |
# | **Psychosocial Stress** | Community programs, VR Earth contacts | Improve mental‑health monitoring; design “psychic” architecture. |
#
# - **Sustainability Initiative**: The *GreenLuna Program* aims to make Luna City a closed‑loop ecosystem by 2090, with minimal resupply from Earth.
#
# ---
#
# ### 11. The Future of Luna City
#
# - **Helium‑3 Fusion Commercialization**: If fusion devices reach *50% efficiency* by 2090, Luna City could supply the entire global energy grid.
# - **Expansion**: Planned “Satellite Settlements” in the far side of the moon, connected via *far‑side Gateway* by 2083.
# - **Mars Connection**: A *Mars‑Lunar Transit Network* (laser‑beam power and robotic supply) expected by 2095.
# - **Education & Culture**: Opening *Moon‑Academy* to students from Mars and the asteroid belt.
#
# ---
#
# ### 12. Key Takeaways
#
# - **Luna City** is a self‑sustaining, free city-state, thriving on regolith technology, Helium‑3 mining, solar energy, and a vibrant multicultural community.
# - It serves as the political, economic, and scientific hub of human presence on the Moon.
# - The city’s architecture and governance model demonstrate how humanity can adapt to the harsh lunar environment while pursuing ambitious scientific and commercial goals.
#
# ---
#
# **Sources** (selected)
# - *NASA Lunar Reconnaissance Orbiter* data (2018‑2025).
# - *International Lunar Authority Charter* (2047).
# - *Lunar Academy Publications* (2022‑2080).
# - *Helium‑3 Extractors Inc. Annual Report* (2078).
# - *SolLuna Energy Transmission Trials* (2025‑2082).
# - *Lunar Health Institute Annual Report* (2079).
#
# *Prepared by: Lunar City Information Office, 8 October 2081.*
