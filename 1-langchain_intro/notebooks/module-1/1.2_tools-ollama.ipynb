# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain_ollama import ChatOllama
from langchain.agents import create_agent

model = ChatOllama(
    model="llama3.1:8b", 
    temperature=0
)

agent = create_agent(
    model=model,
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 467 is approximately 21.61.

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='99b5f5bf-12a5-4bde-8d97-1537e90e6a07'),
#  AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-02T21:10:06.952002521Z', 'done': True, 'done_reason': 'stop', 'total_duration': 26386601753, 'load_duration': 152770701, 'prompt_eval_count': 181, 'prompt_eval_duration': 19472359237, 'eval_count': 19, 'eval_duration': 6708151358, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019b808b-7052-7083-bf33-0120829d8a66-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'ae3ac83e-76c3-4fbf-82f7-48a49b7aad9e', 'type': 'tool_call'}], usage_metadata={'input_tokens': 181, 'output_tokens': 19, 'total_tokens': 200}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='4c10002e-01d3-473d-bc4c-25fdbbd8126a', tool_call_id='ae3ac83e-76c3-4fbf-82f7-48a49b7aad9e'),
#  AIMessage(content='The square root of 467 is approximately 21.61.', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-02T21:10:18.159169195Z', 'done': True, 'done_reason': 'stop', 'total_duration': 11198056259, 'load_duration': 146938718, 'prompt_eval_count': 119, 'prompt_eval_duration': 6127495058, 'eval_count': 14, 'eval_duration': 4873715986, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019b808b-d770-7db2-9f45-304aaadebdd4-0', usage_metadata={'input_tokens': 119, 'output_tokens': 14, 'total_tokens': 133})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': 'ae3ac83e-76c3-4fbf-82f7-48a49b7aad9e', 'type': 'tool_call'}]
