# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

@tool
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool2(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool3(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %%
tool2.invoke({"x": 467})
# Out:
# 21.61018278497431

# %%
tool3.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain_ollama import ChatOllama
from langchain.agents import create_agent

model = ChatOllama(model="qwen3:14b", temperature=0)

agent = create_agent(
    model=model,
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 467 is approximately **21.61018278497431**.
#
# Let me know if you'd like this rounded to a specific decimal place or need further calculations! 😊

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='ecbb5823-7486-4e45-9c01-32df7811e6bc'),
#  AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-07T19:10:16.201259063Z', 'done': True, 'done_reason': 'stop', 'total_duration': 205943304692, 'load_duration': 29721515351, 'prompt_eval_count': 162, 'prompt_eval_duration': 39979810644, 'eval_count': 298, 'eval_duration': 135883893822, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019cc9b1-fa0c-7673-b8c9-6508bffe75fe-0', tool_calls=[{'name': 'tool1', 'args': {'x': 467}, 'id': '6295d1d4-c644-4111-a147-fa9d695bad00', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 162, 'output_tokens': 298, 'total_tokens': 460}),
#  ToolMessage(content='21.61018278497431', name='tool1', id='f18472a2-14d1-4886-89ac-6f52dc111a15', tool_call_id='6295d1d4-c644-4111-a147-fa9d695bad00'),
#  AIMessage(content="The square root of 467 is approximately **21.61018278497431**. \n\nLet me know if you'd like this rounded to a specific decimal place or need further calculations! 😊", additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-07T19:13:59.179972348Z', 'done': True, 'done_reason': 'stop', 'total_duration': 222753299171, 'load_duration': 413034291, 'prompt_eval_count': 213, 'prompt_eval_duration': 12436541910, 'eval_count': 444, 'eval_duration': 209619881781, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019cc9b5-1f59-7770-8ca8-db9811165fd9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 213, 'output_tokens': 444, 'total_tokens': 657})]

# %%
print(response["messages"][1].tool_calls)
