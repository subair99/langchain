"raw_content": null}, {"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner - YouTube", "content": "This Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy", "score": 0.8116913, "raw_content": null}, {"url": "https://www.facebook.com/TheRecipeCritic/posts/grab-you-leftover-rice-and-chicken-toss-it-all-in-a-pan-and-boom-dinner-is-ready/1251345426337809/", "title": "Grab you leftover rice and chicken, toss it all in a pan, and boom ...", "content": "Grab you leftover rice and chicken,... The Recipe Critic\'s Post. ### **The Recipe Critic**. Grab you leftover rice and chicken, toss it all in ...
#               AIMessage(content='Here are a few tasty ways to turn your leftover chicken and rice into a fresh meal:\n\n| Recipe | What you’ll need (in addition to chicken & rice) | Why it’s a good fit |\n|--------|-----------------------------------------------|---------------------|\n| **Classic Chicken Fried Rice** | Soy sauce, sesame oil, garlic, onion, frozen peas & carrots, green onions, egg (optional) | Quick, one‑pan, and the cold rice gives that perfect “fried‑rice” texture. |\n| **Chicken & Rice Casserole** | Cream of mushroom or chicken soup, shredded cheese, frozen peas or broccoli, a splash of milk or broth | Comfort‑food style; you can bake it in a pan or a casserole dish and it’s great for a family dinner. |\n| **Leftover Chicken Egg Fried Rice** | Eggs, soy sauce, garlic, onion, green onions, optional veggies (peas, carrots, corn) | Adds protein and a bit of extra flavor; the eggs give it a richer, more “home‑cooked” feel. |\n\nAll of these use the same core ingredients (chicken + rice) and just add a few pantry staples.  \nWhich one sounds most appealing?  \nIf you’d like the full recipe instructions (ingredients list, step‑by‑step, cooking times, etc.), just let me know the name of the recipe and I’ll send it over!', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2026-02-24T10:07:18.968727538Z', 'done': True, 'done_reason': 'stop', 'total_duration': 198103584788, 'load_duration': 321845283, 'prompt_eval_count': 1382, 'prompt_eval_duration': 117186201983, 'eval_count': 344, 'eval_duration': 80299456990, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019c8f1b-1761-72b2-8a30-d5ebfff920fa-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1382, 'output_tokens': 344, 'total_tokens': 1726})]}

# %%
print(response['messages'][-1].content)
# Out:
# Here are a few tasty ways to turn your leftover chicken and rice into a fresh meal:
#
# | Recipe | What you’ll need (in addition to chicken & rice) | Why it’s a good fit |
# |--------|-----------------------------------------------|---------------------|
# | **Classic Chicken Fried Rice** | Soy sauce, sesame oil, garlic, onion, frozen peas & carrots, green onions, egg (optional) | Quick, one‑pan, and the cold rice gives that perfect “fried‑rice” texture. |
# | **Chicken & Rice Casserole** | Cream of mushroom or chicken soup, shredded cheese, frozen peas or broccoli, a splash of milk or broth | Comfort‑food style; you can bake it in a pan or a casserole dish and it’s great for a family dinner. |
# | **Leftover Chicken Egg Fried Rice** | Eggs, soy sauce, garlic, onion, green onions, optional veggies (peas, carrots, corn) | Adds protein and a bit of extra flavor; the eggs give it a richer, more “home‑cooked” feel. |
#
# All of these use the same core ingredients (chicken + rice) and just add a few pantry staples.
# Which one sounds most appealing?
# If you’d like the full recipe instructions (ingredients list, step‑by‑step, cooking times, etc.), just let me know the name of the recipe and I’ll send it over!

# %%
from IPython.display import display, Markdown

# 1. Your raw string from the model/process
output_text = "### 🥘 Recipe: Chicken Fried Rice\n---\n**Ingredients:** Rice, Chicken..."

# 2. Render it beautifully
display(Markdown(output_text))
