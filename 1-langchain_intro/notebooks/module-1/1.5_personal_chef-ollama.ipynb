# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="qwen3:14b", temperature=0)

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model=model,
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage
from pprint import pprint

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover chicken and rice. What can I make?")]},
    config
)


pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='135ae83f-ffdc-468c-8327-7bc8bda85b55'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-08T15:05:42.384985077Z', 'done': True, 'done_reason': 'stop', 'total_duration': 208614866927, 'load_duration': 30311660280, 'prompt_eval_count': 201, 'prompt_eval_duration': 63829392491, 'eval_count': 248, 'eval_duration': 114005671277, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019ccdf8-6406-7bb1-a831-a88e8280f482-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'recipes with leftover chicken and rice'}, 'id': 'a1cb6b1c-7378-445d-977b-def78d4a045e', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 201, 'output_tokens': 248, 'total_tokens': 449}),
#               ToolMessage(content='{"query": "recipes with leftover chicken and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner - YouTube", "content": "This Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy", "score": 0.9999931, "raw_content": null}, {"url": "https://www.thechunkychef.com/chicken-rice-enchilada-casserole/", "title": "Chicken and Rice Enchilada Casserole - The Chunky Chef", "content": "# Chicken and Rice Enchilada Casserole. **This cheesy, savory, and easy chicken enchilada casserole uses leftover chicken, and is ready in just 35 minutes! *Quick cooking meals are perfect for this time of year… and this chicken enchilada casserole is no exception. That’s why I love recipes like this chicken enchilada casserole! It uses leftover chicken and a really great quick cooking rice to make your prep time nearly non-existent. My absolute favorite way to make this casserole is to use leftover **Tequila Lime chicken**. ## Chicken and Rice Enchilada Casserole. *This cheesy, savory, and easy chicken enchilada casserole uses leftover chicken, and is ready in just 35 minutes! * To a large mixing bowl, add shredded chicken, black beans, green chiles, Mexican corn, cooked rice, 1/2 of the cheese, and enchilada sauce. Love this recipe I make it all the time! This is exactly the kind of dinner I need these days, and I love that you can use leftover chicken!", "score": 0.99983394, "raw_content": null}, {"url": "https://www.facebook.com/TheRecipeCritic/posts/grab-you-leftover-rice-and-chicken-toss-it-all-in-a-pan-and-boom-dinner-is-ready/1251345426337809/", "title": "Grab you leftover rice and chicken, toss it all in a pan, and boom ...", "content": "Tender, seasoned chicken pieces are simmered with aromatic vegetables and fluffy rice in a savory broth until everything is perfectly cooked", "score": 0.9996923, "raw_content": null}, {"url": "https://quickweeknightmeals.com/chicken-fried-rice/", "title": "Chicken Fried Rice - Quick Weeknight Meals", "content": "# Chicken Fried Rice. *Simple and delicious **Chicken Fried Rice** is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.*. I used leftover rotisserie chicken and leftover rice in this. You can\'t go wrong with chicken and rice in a sesame and soy sauce. * **Green onions** - these are going in the fried rice and on top before serving. * **Cold rice** - cold rice makes the best fried rice so use leftover rice or cook the rice the night before. ## How To Make Chicken Fried Rice. * **Add remaining ingredients.** Add rice, chicken, and soy sauce. Chicken fried rice is good for up to 3 days. You can freeze chicken fried rice for up to 3 months. ## Chicken Fried Rice. Simple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner. 5. Add rice, chicken, and soy sauce.", "score": 0.9995859, "raw_content": null}, {"url": "https://streetsmartnutrition.com/easy-weeknight-fried-rice/", "title": "Rotisserie Chicken Fried Rice For An Easy Weeknight Meal", "content": "*This\xa0**Rotisserie Chicken Fried Rice**\xa0recipe uses, you guessed it, leftover rotisserie chicken with white rice, veggies, and plenty of seasoning! * How to Make Rotisserie Chicken Fried Rice. So with that out of the way, let’s get into this recipe for my **Rotisserie Chicken Fried Rice**! This is what inspired this homemade fried rice recipe because my dad always used the leftover rice to make his version of a chicken fried rice recipe the following day. ## How to Make Rotisserie Chicken Fried Rice. While I kept this Rotisserie Chicken Fried Rice recipe simple on purpose, there are plenty of ways to dress it up or customize it! I also love adding a bit of red pepper sauce (like sriracha!) when I serve my ...
#               AIMessage(content='Here are some recipe ideas using your leftover chicken and rice:\n\n1. **Chicken Fried Rice**  \n   - Use cold rice, leftover chicken, soy sauce, green onions, and optional veggies (like peas or carrots). Sauté everything together for a quick, flavorful dish. [Recipe here](https://quickweeknightmeals.com/chicken-fried-rice/).\n\n2. **Chicken and Rice Enchilada Casserole**  \n   - Layer shredded chicken, rice, black beans, green chiles, enchilada sauce, and cheese in a baking dish. Bake until bubbly and golden. [Recipe here](https://www.thechunkychef.com/chicken-rice-enchilada-casserole/).\n\n3. **One-Pan Chicken Rice Stir-Fry**  \n   - Simmer chicken, rice, carrots, celery, and onions in a savory broth for a comforting meal. [Video tutorial here](https://www.youtube.com/watch?v=6ioZjlmtKv8).\n\nWould you like detailed instructions for any of these recipes?', additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-08T15:15:32.829452627Z', 'done': True, 'done_reason': 'stop', 'total_duration': 588241348567, 'load_duration': 231373130, 'prompt_eval_count': 1357, 'prompt_eval_duration': 338366928366, 'eval_count': 423, 'eval_duration': 249226672065, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019ccdfb-9b80-74f3-bfe6-6cbf0bfb542c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1357, 'output_tokens': 423, 'total_tokens': 1780})]}

# %%
print(response['messages'][-1].content)
# Out:
# Here are some recipe ideas using your leftover chicken and rice:
#
# 1. **Chicken Fried Rice**
#    - Use cold rice, leftover chicken, soy sauce, green onions, and optional veggies (like peas or carrots). Sauté everything together for a quick, flavorful dish. [Recipe here](https://quickweeknightmeals.com/chicken-fried-rice/).
#
# 2. **Chicken and Rice Enchilada Casserole**
#    - Layer shredded chicken, rice, black beans, green chiles, enchilada sauce, and cheese in a baking dish. Bake until bubbly and golden. [Recipe here](https://www.thechunkychef.com/chicken-rice-enchilada-casserole/).
#
# 3. **One-Pan Chicken Rice Stir-Fry**
#    - Simmer chicken, rice, carrots, celery, and onions in a savory broth for a comforting meal. [Video tutorial here](https://www.youtube.com/watch?v=6ioZjlmtKv8).
#
# Would you like detailed instructions for any of these recipes?

# %%
from IPython.display import display, Markdown

display(Markdown(response['messages'][-1].content))
# Out:
# Here are some recipe ideas using your leftover chicken and rice:
#
# 1. **Chicken Fried Rice**
#    - Use cold rice, leftover chicken, soy sauce, green onions, and optional veggies (like peas or carrots). Sauté everything together for a quick, flavorful dish. [Recipe here](https://quickweeknightmeals.com/chicken-fried-rice/).
#
# 2. **Chicken and Rice Enchilada Casserole**
#    - Layer shredded chicken, rice, black beans, green chiles, enchilada sauce, and cheese in a baking dish. Bake until bubbly and golden. [Recipe here](https://www.thechunkychef.com/chicken-rice-enchilada-casserole/).
#
# 3. **One-Pan Chicken Rice Stir-Fry**
#    - Simmer chicken, rice, carrots, celery, and onions in a savory broth for a comforting meal. [Video tutorial here](https://www.youtube.com/watch?v=6ioZjlmtKv8).
#
# Would you like detailed instructions for any of these recipes?
