# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain_ollama import ChatOllama
from langchain.agents import create_agent

model = ChatOllama(
    model="gpt-oss:20b", 
    temperature=0
)

agent = create_agent(
    model=model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='16fcb0a5-fea0-4662-89b2-6073c281b3b6'),
#               AIMessage(content='Nice to meet you, Seán! Green is a great choice—there’s something calming and vibrant about it. Do you have a favorite shade of green, or maybe a favorite thing that’s green (like a plant, a car, or a piece of art)?', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2026-02-23T14:59:16.989108542Z', 'done': True, 'done_reason': 'stop', 'total_duration': 122307030824, 'load_duration': 77246603165, 'prompt_eval_count': 79, 'prompt_eval_duration': 11022894969, 'eval_count': 135, 'eval_duration': 33415622067, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019c8b01-3fff-7220-9196-ec7a6f97d13a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 79, 'output_tokens': 135, 'total_tokens': 214})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='0fcb670b-91fa-4f05-a52d-93b69974b92a'),
#               AIMessage(content='I’m not sure—what’s your favourite colour?', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2026-02-23T15:00:05.534155427Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16454339018, 'load_duration': 780257497, 'prompt_eval_count': 72, 'prompt_eval_duration': 1033116320, 'eval_count': 60, 'eval_duration': 14571824222, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019c8b03-8b5e-70a3-8ff4-18bd1527b3e3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 72, 'output_tokens': 60, 'total_tokens': 132})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='49174b31-44f6-431a-b2fd-f36209baca3a'),
#               AIMessage(content="Nice to meet you, Seán! Green's a great choice of favourite colour - it's so calming and natural. What do you like most about the colour green? Is there something in particular that draws you to it?", additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-02T21:41:43.73513629Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16035994978, 'load_duration': 186116208, 'prompt_eval_count': 22, 'prompt_eval_duration': 2246366634, 'eval_count': 46, 'eval_duration': 13497714737, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019b80a8-8a0d-71e3-8bc5-ba342d85ded1-0', usage_metadata={'input_tokens': 22, 'output_tokens': 46, 'total_tokens': 68})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='49174b31-44f6-431a-b2fd-f36209baca3a'),
#               AIMessage(content="Nice to meet you, Seán! Green's a great choice of favourite colour - it's so calming and natural. What do you like most about the colour green? Is there something in particular that draws you to it?", additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-02T21:41:43.73513629Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16035994978, 'load_duration': 186116208, 'prompt_eval_count': 22, 'prompt_eval_duration': 2246366634, 'eval_count': 46, 'eval_duration': 13497714737, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019b80a8-8a0d-71e3-8bc5-ba342d85ded1-0', usage_metadata={'input_tokens': 22, 'output_tokens': 46, 'total_tokens': 68}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='2e6501ce-b810-40e9-a040-dcfb7f133723'),
#               AIMessage(content="Your favourite colour is... GREEN! We already established that, didn't we?", additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-02T21:41:51.734898851Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7979985710, 'load_duration': 148910433, 'prompt_eval_count': 83, 'prompt_eval_duration': 2085535695, 'eval_count': 17, 'eval_duration': 5693137369, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019b80a8-c8ca-7821-bea7-da181dc04d56-0', usage_metadata={'input_tokens': 83, 'output_tokens': 17, 'total_tokens': 100})]}
