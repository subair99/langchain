# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain_ollama import ChatOllama
from langchain.agents import create_agent

model = ChatOllama(
    model="qwen3:14b", 
    temperature=0
)

agent = create_agent(
    model=model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='26ec2729-5fc0-46b4-9f3b-bdee3cc13d6b'),
#               AIMessage(content='Hello Seán! 🌿 Nice to meet you—green is such a beautiful and versatile color! It makes me think of nature, growth, and even the lucky shamrock 🍀. Do you have a special reason for loving green, or is it just the way it makes you feel? 😊', additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-07T19:51:22.913997807Z', 'done': True, 'done_reason': 'stop', 'total_duration': 122761944135, 'load_duration': 18692699027, 'prompt_eval_count': 22, 'prompt_eval_duration': 5696210589, 'eval_count': 217, 'eval_duration': 98198467898, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019cc9d8-e294-72b2-8985-c470da34de50-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 217, 'total_tokens': 239})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='e99d5f73-7233-40b8-9c70-d21dd687fefd'),
#               AIMessage(content="I don't have access to personal information like your favorite color! 😊 Why don't you tell me what your favorite color is, and I can chat about it with you?", additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-07T19:56:52.454662227Z', 'done': True, 'done_reason': 'stop', 'total_duration': 103374067912, 'load_duration': 172401095, 'prompt_eval_count': 16, 'prompt_eval_duration': 2489905491, 'eval_count': 225, 'eval_duration': 100539534900, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019cc9de-3567-78c0-89b5-8f8f9d2322ff-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 225, 'total_tokens': 241})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='33b201aa-b6b5-48eb-9ca2-02de4ac1be5c'),
#               AIMessage(content='Nice to meet you, Seán! Green is a great choice—there’s something calming and vibrant about it. Do you have a favorite shade of green, or maybe a favorite thing that’s green (like a plant, a car, or a piece of art)?', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2026-02-23T15:02:03.155878673Z', 'done': True, 'done_reason': 'stop', 'total_duration': 32222438697, 'load_duration': 268510099, 'prompt_eval_count': 79, 'prompt_eval_duration': 1509963530, 'eval_count': 135, 'eval_duration': 30347310341, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019c8b05-19be-7fb3-8b92-0b3e3114fbab-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 79, 'output_tokens': 135, 'total_tokens': 214})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='33b201aa-b6b5-48eb-9ca2-02de4ac1be5c'),
#               AIMessage(content='Nice to meet you, Seán! Green is a great choice—there’s something calming and vibrant about it. Do you have a favorite shade of green, or maybe a favorite thing that’s green (like a plant, a car, or a piece of art)?', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2026-02-23T15:02:03.155878673Z', 'done': True, 'done_reason': 'stop', 'total_duration': 32222438697, 'load_duration': 268510099, 'prompt_eval_count': 79, 'prompt_eval_duration': 1509963530, 'eval_count': 135, 'eval_duration': 30347310341, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019c8b05-19be-7fb3-8b92-0b3e3114fbab-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 79, 'output_tokens': 135, 'total_tokens': 214}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='a89877a9-8ac0-4d07-9000-c75dd0cddf38'),
#               AIMessage(content='Your favourite colour is green.', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2026-02-23T15:02:50.862413909Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16934685563, 'load_duration': 237784085, 'prompt_eval_count': 148, 'prompt_eval_duration': 6092102962, 'eval_count': 48, 'eval_duration': 10365024398, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019c8b06-0f50-7543-95a1-da4248ee52ac-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 148, 'output_tokens': 48, 'total_tokens': 196})]}
