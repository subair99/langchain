# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain_ollama import ChatOllama
from langchain.agents import create_agent

model = ChatOllama(
    model="qwen3:14b", 
    temperature=0
)

agent = create_agent(
    model=model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='26ec2729-5fc0-46b4-9f3b-bdee3cc13d6b'),
#               AIMessage(content='Hello Seán! 🌿 Nice to meet you—green is such a beautiful and versatile color! It makes me think of nature, growth, and even the lucky shamrock 🍀. Do you have a special reason for loving green, or is it just the way it makes you feel? 😊', additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-07T19:51:22.913997807Z', 'done': True, 'done_reason': 'stop', 'total_duration': 122761944135, 'load_duration': 18692699027, 'prompt_eval_count': 22, 'prompt_eval_duration': 5696210589, 'eval_count': 217, 'eval_duration': 98198467898, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019cc9d8-e294-72b2-8985-c470da34de50-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 217, 'total_tokens': 239})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='e99d5f73-7233-40b8-9c70-d21dd687fefd'),
#               AIMessage(content="I don't have access to personal information like your favorite color! 😊 Why don't you tell me what your favorite color is, and I can chat about it with you?", additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-07T19:56:52.454662227Z', 'done': True, 'done_reason': 'stop', 'total_duration': 103374067912, 'load_duration': 172401095, 'prompt_eval_count': 16, 'prompt_eval_duration': 2489905491, 'eval_count': 225, 'eval_duration': 100539534900, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019cc9de-3567-78c0-89b5-8f8f9d2322ff-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 225, 'total_tokens': 241})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='396900b6-2c71-41c8-a37a-6b1c163936a6'),
#               AIMessage(content='Hello Seán! 🌿 Nice to meet you—green is such a beautiful and versatile color! It makes me think of nature, growth, and even the lucky shamrock 🍀. Do you have a special reason for loving green, or is it just the way it makes you feel? 😊', additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-07T19:59:54.647093991Z', 'done': True, 'done_reason': 'stop', 'total_duration': 100901323118, 'load_duration': 118849672, 'prompt_eval_count': 22, 'prompt_eval_duration': 3662059512, 'eval_count': 217, 'eval_duration': 96989298152, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019cc9e1-06ef-7bf3-b886-98271f3c98ba-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 217, 'total_tokens': 239})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='396900b6-2c71-41c8-a37a-6b1c163936a6'),
#               AIMessage(content='Hello Seán! 🌿 Nice to meet you—green is such a beautiful and versatile color! It makes me think of nature, growth, and even the lucky shamrock 🍀. Do you have a special reason for loving green, or is it just the way it makes you feel? 😊', additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-07T19:59:54.647093991Z', 'done': True, 'done_reason': 'stop', 'total_duration': 100901323118, 'load_duration': 118849672, 'prompt_eval_count': 22, 'prompt_eval_duration': 3662059512, 'eval_count': 217, 'eval_duration': 96989298152, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019cc9e1-06ef-7bf3-b886-98271f3c98ba-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 217, 'total_tokens': 239}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='9c237c9b-ce0a-4a6c-a626-8c84e1dcf043'),
#               AIMessage(content='Your favorite color is **green**! 🌿 I remember you mentioned it earlier—nice choice! It’s such a vibrant and meaningful color. 😊 Would you like to talk more about why you love it?', additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-07T20:03:51.374357857Z', 'done': True, 'done_reason': 'stop', 'total_duration': 92436870747, 'load_duration': 130739290, 'prompt_eval_count': 101, 'prompt_eval_duration': 17396304549, 'eval_count': 164, 'eval_duration': 74760578948, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019cc9e4-c4b7-7900-a53c-0289903b94a5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 101, 'output_tokens': 164, 'total_tokens': 265})]}
