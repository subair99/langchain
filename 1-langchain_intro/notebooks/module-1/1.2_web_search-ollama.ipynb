# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_ollama import ChatOllama
from langchain.agents import create_agent

model = ChatOllama(
    model="qwen3:14b", 
    temperature=0
)

agent = create_agent(
    model=model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# My training knowledge is current up to **October 2024**. This means I have access to information and data from that time, but I cannot provide real-time updates or details about events, technologies, or developments that occurred **after October 2024**.
#
# If you have questions within this timeframe, I’ll do my best to help! For topics beyond this date, I recommend checking the latest sources or updates. Let me know how I can assist! 😊

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Mayor_of_San_Francisco',
#    'title': 'Mayor of San Francisco - Wikipedia',
#    'content': 'The current mayor is Democrat Daniel Lurie.',
#    'score': 0.95324475,
#    'raw_content': None},
#   {'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured city",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.',
#    'score': 0.8755427,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/departments--office-mayor',
#    'title': 'Office of the Mayor - SF.gov',
#    'content': 'Daniel Lurie is the 46th Mayor of the City and County of San Francisco.',
#    'score': 0.8488849,
#    'raw_content': None},
#   {'url': 'https://en.wikipedia.org/wiki/Daniel_Lurie',
#    'title': 'Daniel Lurie - Wikipedia',
#    'content': 'Daniel Lawrence Lurie (born February 4, 1977) is an American politician and philanthropist who is the 46th and incumbent mayor of San Francisco, serving since',
#    'score': 0.82895297,
#    'raw_content': None},
#   {'url': 'https://www.theguardian.com/us-news/2024/nov/07/san-francisco-mayor-election',
#    'title': 'Levi Strauss heir Daniel Lurie elected mayor of San Francisco',
#    'content': 'Levi Strauss heir Daniel Lurie elected mayor of San Francisco. Wealthy Democratic outsider unseats incumbent mayor London Breed in expensive race.',
#    'score': 0.82186085,
#    'raw_content': None}],
#  'response_time': 0.62,
#  'request_id': '6fd2723d-8021-414d-ac6a-555a10f534a7'}

# %%
agent = create_agent(
    model=model,
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='56fad1b7-a8a5-48b1-b554-e698f19bdc48'),
#  AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-07T19:36:47.355970002Z', 'done': True, 'done_reason': 'stop', 'total_duration': 146115606985, 'load_duration': 17799990973, 'prompt_eval_count': 138, 'prompt_eval_duration': 31534097311, 'eval_count': 209, 'eval_duration': 96592390798, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019cc9cb-2b35-7b62-99bf-bd01735d1fa7-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current mayor of San Francisco'}, 'id': '1b15e1a9-22d4-4d33-a469-5c9fc7219526', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 138, 'output_tokens': 209, 'total_tokens': 347}),
#  ToolMessage(content='{"query": "current mayor of San Francisco", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://en.wikipedia.org/wiki/Mayor_of_San_Francisco", "title": "Mayor of San Francisco - Wikipedia", "content": "The current mayor is Democrat Daniel Lurie.", "score": 0.94251215, "raw_content": null}, {"url": "https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0", "title": "San Francisco\'s new mayor is starting to unite the fractured city", "content": "San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.", "score": 0.8745175, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=jKlTyBxpyT4", "title": "San Francisco\'s new mayor is starting to unite the fractured city", "content": "San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on,", "score": 0.85967577, "raw_content": null}, {"url": "https://www.sf.gov/departments--office-mayor", "title": "Office of the Mayor - SF.gov", "content": "Daniel Lurie is the 46th Mayor of the City and County of San Francisco.", "score": 0.8449346, "raw_content": null}, {"url": "https://www.cbsnews.com/sanfrancisco/news/san-francisco-mayor-elect-daniel-lurie-claims-victory-outlines-vision-for-city/", "title": "San Francisco Mayor-elect Daniel Lurie claims victory, outlines ...", "content": "San Francisco\'s Mayor-elect Daniel Lurie declared victory Friday morning as he addressed the city for the first time since incumbent Mayor London Breed", "score": 0.834852, "raw_content": null}], "response_time": 0.74, "request_id": "801c4410-2459-442d-9490-245287d417cb"}', name='web_search', id='fcc08d30-80ac-419e-a39b-4263d4283df4', tool_call_id='1b15e1a9-22d4-4d33-a469-5c9fc7219526'),
#  AIMessage(content='The current mayor of San Francisco is **Daniel Lurie**, who has been serving in this role since 2024. He is the 46th mayor of the City and County of San Francisco.', additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-07T19:40:51.890082376Z', 'done': True, 'done_reason': 'stop', 'total_duration': 242617671670, 'load_duration': 149771444, 'prompt_eval_count': 722, 'prompt_eval_duration': 146115029159, 'eval_count': 194, 'eval_duration': 96207403788, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019cc9cd-6d74-7d61-90a4-ec7ed8ca470b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 722, 'output_tokens': 194, 'total_tokens': 916})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
