# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="gpt-oss:20b", temperature=0)

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

system_prompt = """You are a travel agent. 
IMPORTANT: When using the search-flight tool, you MUST use the following rules:
1. Dates must be in 'dd/mm/yyyy' format (e.g., 31/03/2026).
2. All dates must be in the future.
3. If the user asks for a one-way flight, ensure you still provide the correct parameters required by the tool.
4. Use only English Language
No follow up questions."""

agent = create_agent(
    model=model,
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt=system_prompt
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Create an effective prompt template for getting flights")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Create an effective prompt template for getting flights', additional_kwargs={}, response_metadata={}, id='48c536b7-30fb-4c04-b7c9-043fafb2ab8e'),
#               AIMessage(content='**Prompt Template for Requesting Flights**\n\nUse the following structure to ask for flight information. Replace the placeholders with your specific details.\n\n| Field | Description | Example |\n|-------|-------------|---------|\n| **Departure city / airport** | Where you will leave from (city name, airport name, or IATA code). | “New York (JFK)” |\n| **Destination city / airport** | Where you want to go (city name, airport name, or IATA code). | “London (LHR)” |\n| **Departure date** | Date of departure in `dd/mm/yyyy` format. | `15/07/2026` |\n| **Return date** *(optional)* | Date of return in `dd/mm/yyyy` format. | `22/07/2026` |\n| **Cabin class** | Preferred cabin: `M` (economy), `W` (economy premium), `C` (business), `F` (first). | `M` |\n| **Currency** | Desired currency for pricing (e.g., `USD`, `EUR`). | `USD` |\n| **Number of passengers** | Adults, children, infants (total 1‑9, at least one adult). | `{"adults":2,"children":1,"infants":0}` |\n| **Departure date flexibility** | Days before/after the chosen departure date (0‑3). | `1` |\n| **Return date flexibility** | Days before/after the chosen return date (0‑3). | `2` |\n| **Locale** | Language for city names and links (`en`, `de`, `fr`, etc.). | `en` |\n| **Sort preference** | How to sort results: `price`, `duration`, `quality`, `date`. | `price` |\n\n---\n\n### Example Prompt\n\n> **Flight Search Request**  \n> - **From:** New York (JFK)  \n> - **To:** London (LHR)  \n> - **Departure:** 15/07/2026 (±1 day)  \n> - **Return:** 22/07/2026 (±2 days)  \n> - **Cabin:** M (Economy)  \n> - **Currency:** USD  \n> - **Passengers:** `{"adults":2,"children":1,"infants":0}`  \n> - **Locale:** en  \n> - **Sort:** price  \n\nFeel free to adjust any field to match your travel preferences.', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2026-03-04T16:55:20.342638383Z', 'done': True, 'done_reason': 'stop', 'total_duration': 316567712689, 'load_duration': 56774810729, 'prompt_eval_count': 1066, 'prompt_eval_duration': 113680793617, 'eval_count': 565, 'eval_duration': 144604684885, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019cb9c1-da8a-75c1-a773-65f59870c65f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1066, 'output_tokens': 565, 'total_tokens': 1631})]}

# %%
print(response["messages"][-1].content)
# Out:
# **Prompt Template for Requesting Flights**
#
# Use the following structure to ask for flight information. Replace the placeholders with your specific details.
#
# | Field | Description | Example |
# |-------|-------------|---------|
# | **Departure city / airport** | Where you will leave from (city name, airport name, or IATA code). | “New York (JFK)” |
# | **Destination city / airport** | Where you want to go (city name, airport name, or IATA code). | “London (LHR)” |
# | **Departure date** | Date of departure in `dd/mm/yyyy` format. | `15/07/2026` |
# | **Return date** *(optional)* | Date of return in `dd/mm/yyyy` format. | `22/07/2026` |
# | **Cabin class** | Preferred cabin: `M` (economy), `W` (economy premium), `C` (business), `F` (first). | `M` |
# | **Currency** | Desired currency for pricing (e.g., `USD`, `EUR`). | `USD` |
# | **Number of passengers** | Adults, children, infants (total 1‑9, at least one adult). | `{"adults":2,"children":1,"infants":0}` |
# | **Departure date flexibility** | Days before/after the chosen departure date (0‑3). | `1` |
# | **Return date flexibility** | Days before/after the chosen return date (0‑3). | `2` |
# | **Locale** | Language for city names and links (`en`, `de`, `fr`, etc.). | `en` |
# | **Sort preference** | How to sort results: `price`, `duration`, `quality`, `date`. | `price` |
#
# ---
#
# ### Example Prompt
#
# > **Flight Search Request**
# > - **From:** New York (JFK)
# > - **To:** London (LHR)
# > - **Departure:** 15/07/2026 (±1 day)
# > - **Return:** 22/07/2026 (±2 days)
# > - **Cabin:** M (Economy)
# > - **Currency:** USD
# > - **Passengers:** `{"adults":2,"children":1,"infants":0}`
# > - **Locale:** en
# > - **Sort:** price
#
# Feel free to adjust any field to match your travel preferences.

# %%
user_prompt = """
Flight Search Request
From: JFK
To: LHR
Departure: 04/04/2026 (±1 day)
Return: 02/05/2026 (±1 days)
Cabin: M (Economy)
Currency: USD
Passengers: { adults:1, children:0, infants:0 }
Locale: en
Sort by: price
"""

# %%
from langchain.messages import HumanMessage

response = await agent.ainvoke(
    {"messages": [HumanMessage(content=user_prompt)]},
    config
    )

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Create an effective prompt template for getting flights', additional_kwargs={}, response_metadata={}, id='48c536b7-30fb-4c04-b7c9-043fafb2ab8e'),
#               AIMessage(content='**Prompt Template for Requesting Flights**\n\nUse the following structure to ask for flight information. Replace the placeholders with your specific details.\n\n| Field | Description | Example |\n|-------|-------------|---------|\n| **Departure city / airport** | Where you will leave from (city name, airport name, or IATA code). | “New York (JFK)” |\n| **Destination city / airport** | Where you want to go (city name, airport name, or IATA code). | “London (LHR)” |\n| **Departure date** | Date of departure in `dd/mm/yyyy` format. | `15/07/2026` |\n| **Return date** *(optional)* | Date of return in `dd/mm/yyyy` format. | `22/07/2026` |\n| **Cabin class** | Preferred cabin: `M` (economy), `W` (economy premium), `C` (business), `F` (first). | `M` |\n| **Currency** | Desired currency for pricing (e.g., `USD`, `EUR`). | `USD` |\n| **Number of passengers** | Adults, children, infants (total 1‑9, at least one adult). | `{"adults":2,"children":1,"infants":0}` |\n| **Departure date flexibility** | Days before/after the chosen departure date (0‑3). | `1` |\n| **Return date flexibility** | Days before/after the chosen return date (0‑3). | `2` |\n| **Locale** | Language for city names and links (`en`, `de`, `fr`, etc.). | `en` |\n| **Sort preference** | How to sort results: `price`, `duration`, `quality`, `date`. | `price` |\n\n---\n\n### Example Prompt\n\n> **Flight Search Request**  \n> - **From:** New York (JFK)  \n> - **To:** London (LHR)  \n> - **Departure:** 15/07/2026 (±1 day)  \n> - **Return:** 22/07/2026 (±2 days)  \n> - **Cabin:** M (Economy)  \n> - **Currency:** USD  \n> - **Passengers:** `{"adults":2,"children":1,"infants":0}`  \n> - **Locale:** en  \n> - **Sort:** price  \n\nFeel free to adjust any field to match your travel preferences.', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2026-03-04T16:55:20.342638383Z', 'done': True, 'done_reason': 'stop', 'total_duration': 316567712689, 'load_duration': 56774810729, 'prompt_eval_count': 1066, 'prompt_eval_duration': 113680793617, 'eval_count': 565, 'eval_duration': 144604684885, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019cb9c1-da8a-75c1-a773-65f59870c65f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1066, 'output_tokens': 565, 'total_tokens': 1631}),
#               HumanMessage(content='\nI need a flight from New York (JFK) to London (LHR).\nDeparture: 04/04/2026 (±1 day)\nReturn: 02/05/2026 (±1 days)\nCabin: M (Economy)\nCurrency: USD\nPassengers: { adults:1, children:0, infants:0 }\nSort by: price\nLocale: en\n', additional_kwargs={}, response_metadata={}, id='fb2d55d2-fc78-476e-a3d8-3a422f92f298'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2026-03-04T16:57:11.050837889Z', 'done': True, 'done_reason': 'stop', 'total_duration': 113705800133, 'load_duration': 432608234, 'prompt_eval_count': 1673, 'prompt_eval_duration': 72233755501, 'eval_count': 162, 'eval_duration': 40872481790, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019cb9c6-838e-7c63-8e18-f7dd99db1331-0', tool_calls=[{'name': 'search-flight', 'args': {'cabinClass': 'M', 'curr': 'USD', 'departureDate': '04/04/2026', 'departureDateFlexRange': 1, 'flyFrom': 'New York (JFK)', 'flyTo': 'London (LHR)', 'locale': 'en', 'passengers': {'adults': 1, 'children': 0, 'infants': 0}, 'returnDate': '02/05/2026', 'returnDateFlexRange': 1, 'sort': 'price'}, 'id': 'b159d349-a99a-4a3a-8b16-4926fd607099', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1673, 'output_tokens': 162, 'total_tokens': 1835}),
#               ToolMessage(content=[{'type': 'text', 'text': 'No locations found. Ask the user to provide a valid location: it can be a city or an airport name or code.', 'id': 'lc_4baae19b-b183-4fa6-9993-99dbd421c7eb'}], name='search-flight', id='94554987-8782-43ba-ac22-a5b318fced10', tool_call_id='b159d349-a99a-4a3a-8b16-4926fd607099'),
#               AIMessage(content='I’m sorry, but I couldn’t locate the departure or arrival airports you specified. Please double‑check the city or airport names (or use the IATA codes, e.g., “JFK” for New\u202fYork and “LHR” for London) and try again.', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2026-03-04T16:58:50.472643052Z', 'done': True, 'done_reason': 'stop', 'total_duration': 98713023670, 'load_duration': 297085299, 'prompt_eval_count': 1811, 'prompt_eval_duration': 18220635058, 'eval_count': 297, 'eval_duration': 79865661837, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019cb9c8-483a-7e23-8305-2cf46fdd04a4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1811, 'output_tokens': 297, 'total_tokens': 2108})]}

# %%
print(response["messages"][-1].content)
# Out:
# I’m sorry, but I couldn’t locate the departure or arrival airports you specified. Please double‑check the city or airport names (or use the IATA codes, e.g., “JFK” for New York and “LHR” for London) and try again.
